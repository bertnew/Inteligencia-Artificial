# %% [markdown]
# <a href="https://colab.research.google.com/github/bertnew/Inteligencia-Artificial/blob/main/mental_health_pre_screening_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sources:
# handsonai.medium.com (1)
# tensorflow.org (2)
# blog.tensorflow.org (3)
# geeksforgeeks.org (4)

# %% [markdown]
# Code for a mental health pre-screening chatbot with natural language processing using TensorFlow and specific libraries.
#
# how you can start building one using TensorFlow and relevant libraries.

# %%
# First, you need to install TensorFlow and other required libraries.
# You can use Google Colab to write and run the code.
# Here's how you can install the necessary libraries:

# %%
# !pip install tensorflow
# !pip install nltk
# !pip install spacy
# !pip install transformers

# %%
# Next, you can start building the chatbot by importing the necessary
# libraries and preprocessing the data.

# %%
# import nltk
# import spacy
# import transformers
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
# from spacy.lang.en.stop_words import STOP_WORDS
# from transformers import AutoTokenizer, TFAutoModelForMaskedLM

# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('stopwords')

# nlp = spacy.load('en_core_web_sm')
# tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# model = TFAutoModelForMaskedLM.from_pretrained('bert-base-uncased')
# lemmatizer = WordNetLemmatizer()
# stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# All PyTorch model weights were used when initializing TFBertForMaskedLM.
#
# All the weights of TFBertForMaskedLM were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForMaskedLM for predictions without further training.

# %%
# !pip install transformers sentencepiece

# %%
# from transformers import MarianMTModel, MarianTokenizer

# %%
# def simple_translator():
#     model_name = 'Helsinki-NLP/opus-mt-en-es'
#     model = MarianMTModel.from_pretrained(model_name)
#     tokenizer = MarianTokenizer.from_pretrained(model_name)

# while True:
#         # Recibir texto en inglés del usuario
#         text = input("Ingresa el texto en inglés a traducir (o 'salir' para terminar): ")
#         if text.lower() == 'salir':
#             break

# translated = model.generate(**tokenizer(text, return_tensors="pt", padding=True))

# translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)
# print(f"Traducción al español: {translated_text}\n")

# %%
# if __name__ == "__main__":
#     simple_translator()

# %%
# After preprocessing the data, you can define the intents and entities
# for the chatbot.

# %%
# intents = [
#     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey']},
#     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
#     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# ]

# entities = [
#     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress']}
# ]

# %%
# intents = [
#     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey', 'good morning/afternoon/evening', 'how do you do?', 'pleased to meet you', 'it is a pleasure to meet you', 'good to see you', 'howdy', 'what is up?', 'how is it going?','long time no see' ,'hey there','hey man' , 'hey girl','what is new?','how are you doing?', 'all right, mate?', 'howyasay', 'g day','hola', 'que tal', 'guten tag', 'blimey! It is you!', 'hello there! how are you today?', 'how are you doing today?','howdy doody', 'top of the morning to you', 'greetings']},
#     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
#     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# ]

# entities = [
#     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress', 'worry', 'burden', 'load', 'concern','weight', 'mild', 'severe', 'tightness', 'tension', 'ache', 'pain','strain', 'job stress', 'financial stress', 'relationship stress', 'exam stress', 'public speaking stress', 'at my wit is end','be on edge', 'be under a gun', 'crack under pressure', 'feel like i am going to explode', 'have a lot of my plate', 'lose sleep over something', 'pull an all-nighter', 'sweet the small stuff', 'take it one day at a  time','the pressure is on', 'under pressure', 'wrack my brain' ]}
# ]

# initial_greeting_corpus = [
#     'hi',
#     'hello',
#     'hey',
#     'greetings',
#     'good morning',
#     'good afternoon',
#     'good evening',
#     'welcome',
#     'start chat',
#     'begin conversation'
# ]

# questionnaire_corpus = [
#     'start test',
#     'begin test',
#     'start questionnaire',
#     'mental health test',
#     'assess my mood',
#     'check my feelings',
#     'evaluate my mental health',
#     'answer some questions'
# ]

# end_conversation_corpus = [
#     'quit',
#     'exit',
#     'goodbye',
#     'bye',
#     'see you later',
#     'end chat',
#     'finish conversation',
#     'stop chatting'
# ]

# %%
# Next, you can define the conversation flow for the chatbot.

# %%
# def respond(user_input):
#     user_input = nlp(user_input)
#     user_input = [token.lemma_.lower().strip() for token in user_input if token.lemma_ != '-PRON-' and token.lemma_ not in stop_words]
#     user_input = ' '.join(user_input)

#     input_ids = tokenizer.encode(user_input, return_tensors='tf')
#     masked_lm_outputs = model(input_ids)
#     predicted_token = tf.argmax(masked_lm_outputs[0][:, 1, :], axis=-1)
#     predicted_token = tokenizer.decode(predicted_token[0])

#     if predicted_token in ['hi', 'hello', 'hey']:
#         return 'Hello! How can I help you with your mental health today?'
#     elif predicted_token in ['bye', 'goodbye', 'see you later']:
#         return 'Goodbye! Take care.'
#     elif predicted_token.lower() == 'start test' or predicted_token.lower() == 'begin test' or predicted_token.lower() == 'start questionnaire':
#         return 'Sure, I can help you with that. Let\'s start with some questions about your mental health. Have you been feeling down, depressed, or hopeless?',
#     else:
#         return 'I\'m sorry, I didn\'t understand that. Can you please rephrase it?'

# def handle_questionnaire():
#     print("Let's start the mental health questionnaire:")
#     questionnaire = [
#         "Have you had difficulty sleeping for more than two weeks?",
#         "Have you lost interest in activities you used to enjoy?",
#         "Do you feel sad or depressed most of the time?",
#         '¿Ha tenido dificultades para dormir durante más de dos semanas?',
#         '¿Ha perdido el interés en actividades que solía disfrutar?',
#         '¿Se siente triste o deprimido la mayor parte del tiempo?',
#         '¿Tiene pensamientos negativos sobre usted mismo o el mundo?',
#         '¿Ha tenido problemas para concentrarse o recordar cosas?',
#         '¿Siente que se mueve más lento o que sus movimientos son torpes?',
#         '¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?',
#         '¿Se siente agitado o ansioso la mayor parte del tiempo?',
#         '¿Tiene problemas para conciliar el sueño o despertarse temprano?',
#         '¿Se siente irritable o fácilmente molesto?',
#         '¿Se siente fatigado o sin energía la mayor parte del tiempo?',
#         '¿Ha tenido problemas para controlar su impulso o comportamiento?',
#         '¿Se ha sentido inseguro o preocupado por su apariencia física?',
#         '¿Ha tenido problemas para relacionarse con los demás?',
#         '¿Se ha sentido como si estuviera observando su vida desde afuera?',
#         '¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?',
#         '¿Ha tenido un episodio de manía o hipomanía?',
#         '¿Ha tenido problemas con el abuso de sustancias o el alcohol?',
#         '¿Ha tenido problemas para seguir con sus responsabilidades diarias?',
#         '¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?',
#         '¿Ha pensado en buscar ayuda profesional para su salud mental?',
#         '¿Ha recibido tratamiento para su salud mental en el pasado?',
#         '¿Tiene antecedentes familiares de trastornos mentales?',
#         '¿Tiene otras condiciones médicas que podrían afectar su salud mental?',
#         '¿Toma algún medicamento que podría afectar su salud mental?',
#         '¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?',
#         '¿Ha tenido experiencias traumáticas en el pasado?',
#         '¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?',
#         '¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?',
#         '¿Está dispuesto a buscar ayuda profesional si es necesario?',
#         # ... (add the rest of the questions)
#     ]

#     answers = []
#     for question in questionnaire:
#         user_answer = input(question + " (yes/no): ").lower()
#         answers.append(user_answer)

# # Perform sentiment analysis on the questionnaire responses
#     sentiment_result = perform_sentiment_analysis(answers)
#     print("Sentiment analysis result for the questionnaire: ", sentiment_result)


# def chatbot_response(user_input):
#     response = respond(user_input)
#     print('Chatbot: ' + response)
#     return response

# %%
# Finally, you can add clear disclaimers and refer users
# to appropriate mental health resources if they
# indicate that they may be experiencing mental health symptoms.

# %%
# def disclaimer():
#     print('Disclaimer: This chatbot is not a substitute for professional medical advice. It is intended to provide general information and support.')
#     print('If you are experiencing mental health symptoms, please seek professional help.')
#     print('This chatbot is not intended to diagnose, treat, or cure any mental health conditions.')
#     print('User data may be shared with third parties for the purpose of providing and improving the chatbot.')
#     print('If you are in crisis, please seek professional help immediately.')
#     print('You can contact the National Suicide Prevention Lifeline at 1-800-273-TALK (1-800-273-8255) or text "MHA" to 741741 to speak with a trained crisis counselor.')

# disclaimer()

# %%
# if any(greeting_pattern in user_input.lower() for greeting_pattern in initial_greeting_corpus):
#         initial_greeting()
# elif any(questionnaire_pattern in user_input.lower() for questionnaire_pattern in questionnaire_corpus):
#         handle_questionnaire()
# elif any(end_pattern in user_input.lower() for end_pattern in end_conversation_corpus):
#         print("Ending the conversation. Goodbye!")
#                  break

# %%
# You can then use the chatbot_response function to
# interact with the chatbot.

# %%
# while True:
#     user_input = input('You: ')
#     if user_input.lower() == 'quit':
#         break
#     chatbot_response(user_input)

# %% [markdown]
# Sources: anenadic.github.io (1) discuss.codecademy.com (2) ipython.org (3) southampton.ac.uk (4)
#
# The error message "NameError: name '' is not defined indicates that the TensorFlow library has not been imported or initialized properly. In the code you provided, TensorFlow is imported with !pip install tensor, but it should be imported as a Python module with import tensorflow as tf.
#
# Here's the corrected code:

# %%
# Sources:
# anenadic.github.io (1)
# discuss.codecademy.com (2)
# ipython.org (3)
# southampton.ac.uk (4)

# %%
# import tensorflow as tf
# import nltk
# import spacy
# import transformers
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
# from spacy.lang.en.stop_words import STOP_WORDS
# from transformers import AutoTokenizer, TFAutoModelForMaskedLM

# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('stopwords')

# nlp = spacy.load('en_core_web_sm')
# tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# model = TFAutoModelForMaskedLM.from_pretrained('bert-base-uncased')
# lemmatizer = WordNetLemmatizer()
# stop_words = set(stopwords.words('english'))

# intents = [
#     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey', 'good morning/afternoon/evening', 'how do you do?', 'pleased to meet you', 'it is a pleasure to meet you', 'good to see you', 'howdy', 'what is up?', 'how is it going?','long time no see' ,'hey there','hey man' , 'hey girl','what is new?','how are you doing?', 'all right, mate?', 'howyasay', 'g day','hola', 'que tal', 'guten tag', 'blimey! It is you!', 'hello there! how are you today?', 'how are you doing today?','howdy doody', 'top of the morning to you', 'greetings']},
#     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
#     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# ]

# entities = [
#     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress', 'worry', 'burden', 'load', 'concern','weight', 'mild', 'severe', 'tightness', 'tension', 'ache', 'pain','strain', 'job stress', 'financial stress', 'relationship stress', 'exam stress', 'public speaking stress', 'at my wit is end','be on edge', 'be under a gun', 'crack under pressure', 'feel like i am going to explode', 'have a lot of my plate', 'lose sleep over something', 'pull an all-nighter', 'sweet the small stuff', 'take it one day at a  time','the pressure is on', 'under pressure', 'wrack my brain' ]}
# ]

# initial_greeting_corpus = [
#     'hi',
#     'hello',
#     'hey',
#     'greetings',
#     'good morning',
#     'good afternoon',
#     'good evening',
#     'welcome',
#     'start chat',
#     'begin conversation'
# ]

# questionnaire_corpus = [
#     'start test',
#     'begin test',
#     'start questionnaire',
#     'mental health test',
#     'assess my mood',
#     'check my feelings',
#     'evaluate my mental health',
#     'answer some questions'
# ]

# end_conversation_corpus = [
#     'quit',
#     'exit',
#     'goodbye',
#     'bye',
#     'see you later',
#     'end chat',
#     'finish conversation',
#     'stop chatting'
# ]

# # intents = [
# #     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey']},
# #     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
# #     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# # ]

# # entities = [
# #     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress']}
# # ]

# def respond(user_input):
#     user_input = nlp(user_input)
#     user_input = [token.lemma_.lower().strip() for token in user_input if token.lemma_ != '-PRON-' and token.lemma_ not in stop_words]
#     user_input = ' '.join(user_input)

#     input_ids = tokenizer.encode(user_input, return_tensors='tf')
#     masked_lm_outputs = model(input_ids)
#     predicted_token = tf.argmax(masked_lm_outputs[0][:, 1, :], axis=-1)
#     predicted_token = tokenizer.decode(predicted_token[0])

#     if predicted_token in ['hi', 'hello', 'hey']:
#         return 'Hello! How can I help you with your mental health today?'
#     elif predicted_token in ['bye', 'goodbye', 'see you later']:
#         return 'Goodbye! Take care.'
#     elif predicted_token.lower() == 'start test' or predicted_token.lower() == 'begin test' or predicted_token.lower() == 'start questionnaire':
#         return 'Sure, I can help you with that. Let\'s start with some questions about your mental health. Have you been feeling down, depressed, or hopeless?',
#     else:
#         return 'I\'m sorry, I didn\'t understand that. Can you please rephrase it?'

# def handle_questionnaire():
#        print("Let's start the mental health questionnaire:")

#        questionnaire = [
#         "Have you had difficulty sleeping for more than two weeks?",
#         "Have you lost interest in activities you used to enjoy?",
#         "Do you feel sad or depressed most of the time?",
#         '¿Ha tenido dificultades para dormir durante más de dos semanas?',
#         '¿Ha perdido el interés en actividades que solía disfrutar?',
#         '¿Se siente triste o deprimido la mayor parte del tiempo?',
#         '¿Tiene pensamientos negativos sobre usted mismo o el mundo?',
#         '¿Ha tenido problemas para concentrarse o recordar cosas?',
#         '¿Siente que se mueve más lento o que sus movimientos son torpes?',
#         '¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?',
#         '¿Se siente agitado o ansioso la mayor parte del tiempo?',
#         '¿Tiene problemas para conciliar el sueño o despertarse temprano?',
#         '¿Se siente irritable o fácilmente molesto?',
#         '¿Se siente fatigado o sin energía la mayor parte del tiempo?',
#         '¿Ha tenido problemas para controlar su impulso o comportamiento?',
#         '¿Se ha sentido inseguro o preocupado por su apariencia física?',
#         '¿Ha tenido problemas para relacionarse con los demás?',
#         '¿Se ha sentido como si estuviera observando su vida desde afuera?',
#         '¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?',
#         '¿Ha tenido un episodio de manía o hipomanía?',
#         '¿Ha tenido problemas con el abuso de sustancias o el alcohol?',
#         '¿Ha tenido problemas para seguir con sus responsabilidades diarias?',
#         '¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?',
#         '¿Ha pensado en buscar ayuda profesional para su salud mental?',
#         '¿Ha recibido tratamiento para su salud mental en el pasado?',
#         '¿Tiene antecedentes familiares de trastornos mentales?',
#         '¿Tiene otras condiciones médicas que podrían afectar su salud mental?',
#         '¿Toma algún medicamento que podría afectar su salud mental?',
#         '¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?',
#         '¿Ha tenido experiencias traumáticas en el pasado?',
#         '¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?',
#         '¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?',
#         '¿Está dispuesto a buscar ayuda profesional si es necesario?',
#         # ... (add the rest of the questions)
#       ]

# answers = []

# for question in questionnaire:
#         user_answer = input(question + " (yes/no): ").lower()
#         answers.append(user_answer)

# # Perform sentiment analysis on the questionnaire responses

#         sentiment_result = perform_sentiment_analysis(answers)
#         print("Sentiment analysis result for the questionnaire: ", sentiment_result)


# # Process answers or take further actions based on the responses

# def chatbot_response(user_input):
#     response = respond(user_input)
#     print('Chatbot: ' + response)
#     return response


# disclaimer()

# %%
#  if any(greeting_pattern in user_input.lower() for greeting_pattern in initial_greeting_corpus):
#         initial_greeting()
#     elif any(questionnaire_pattern in user_input.lower() for questionnaire_pattern in questionnaire_corpus):
#         handle_questionnaire()
#     elif any(end_pattern in user_input.lower() for end_pattern in end_conversation_corpus):
#         print("Ending the conversation. Goodbye!")
# #         break

# %%
#

# %%
# while True:
#     user_input = input('You: ')
#     if user_input.lower() == 'quit':
#         break
#     chatbot_response(user_input)

# %% [markdown]
# To build a mental health chatbot using TensorFlow and relevant libraries, you can follow these steps:
#
# Install TensorFlow and other required libraries, such as NLTK, SpaCy, and Transformers, using pip.
#
# Preprocess the data by tokenizing, lowercasing, removing stop words, and lemmatizing the text.
#
# Define the intents and entities for the chatbot, such as greetings, goodbyes, and mental health conditions.
#
# Define the conversation flow for the chatbot using a function that takes in user input, preprocesses it, and generates a response based on the predicted token.
#
# Add clear disclaimers and refer users to appropriate mental health resources if they indicate that they may be experiencing mental health symptoms.
# Test the chatbot by interacting with it and handling any errors that may arise.
#
# Here is an example code that demonstrates how to build a mental health chatbot using TensorFlow and relevant libraries:
#
# python

# %%
# import tensorflow as tf
# import nltk
# import spacy
# import transformers
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
# from spacy.lang.en.stop_words import STOP_WORDS
# from transformers import AutoTokenizer, TFAutoModelForMaskedLM

# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('stopwords')

# nlp = spacy.load('en_core_web_sm')
# tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# model = TFAutoModelForMaskedLM.from_pretrained('bert-base-uncased')
# lemmatizer = WordNetLemmatizer()
# stop_words = set(stopwords.words('english'))

# # intents = [
# #     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey']},
# #     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
# #     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# # ]

# # entities = [
# #     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress']}
# # ]


# intents = [
#     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey', 'good morning/afternoon/evening', 'how do you do?', 'pleased to meet you', 'it is a pleasure to meet you', 'good to see you', 'howdy', 'what is up?', 'how is it going?','long time no see' ,'hey there','hey man' , 'hey girl','what is new?','how are you doing?', 'all right, mate?', 'howyasay', 'g day','hola', 'que tal', 'guten tag', 'blimey! It is you!', 'hello there! how are you today?', 'how are you doing today?','howdy doody', 'top of the morning to you', 'greetings']},
#     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
#     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# ]

# entities = [
#     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress', 'worry', 'burden', 'load', 'concern','weight', 'mild', 'severe', 'tightness', 'tension', 'ache', 'pain','strain', 'job stress', 'financial stress', 'relationship stress', 'exam stress', 'public speaking stress', 'at my wit is end','be on edge', 'be under a gun', 'crack under pressure', 'feel like i am going to explode', 'have a lot of my plate', 'lose sleep over something', 'pull an all-nighter', 'sweet the small stuff', 'take it one day at a  time','the pressure is on', 'under pressure', 'wrack my brain' ]}
# ]

# initial_greeting_corpus = [
#     'hi',
#     'hello',
#     'hey',
#     'greetings',
#     'good morning',
#     'good afternoon',
#     'good evening',
#     'welcome',
#     'start chat',
#     'begin conversation'
# ]

# questionnaire_corpus = [
#     'start test',
#     'begin test',
#     'start questionnaire',
#     'mental health test',
#     'assess my mood',
#     'check my feelings',
#     'evaluate my mental health',
#     'answer some questions'
# ]

# end_conversation_corpus = [
#     'quit',
#     'exit',
#     'goodbye',
#     'bye',
#     'see you later',
#     'end chat',
#     'finish conversation',
#     'stop chatting'
# ]

# def preprocess(text):
#     doc = nlp(text)
#     tokens = [token.lemma_.lower().strip() for token in doc if token.lemma_ != '-PRON-' and token.lemma_ not in stop_words]
#     return ' '.join(tokens)

# def respond(user_input):
#     user_input = preprocess(user_input)
#     input_ids = tokenizer.encode(user_input, return_tensors='tf')
#     masked_lm_outputs = model(input_ids)
#     predicted_token = tf.argmax(masked_lm_outputs[0][:, 1, :], axis=-1)
#     predicted_token = tokenizer.decode(predicted_token[0])

#     if predicted_token in ['hi', 'hello', 'hey']:
#         return 'Hello! How can I help you with your mental health today?'
#     elif predicted_token in ['bye', 'goodbye', 'see you later']:
#         return 'Goodbye! Take care.'
#     elif predicted_token.lower() == 'start test' or predicted_token.lower() == 'begin test' or predicted_token.lower() == 'start questionnaire':
#         return 'Sure, I can help you with that. Let\'s start with some questions about your mental health. Have you been feeling down, depressed, or hopeless?',
#     else:
#         return 'I\'m sorry, I didn\'t understand that. Can you please rephrase it?'
#         def handle_questionnaire():
#         print("Let's start the mental health questionnaire:")

#     questionnaire = [
#         "Have you had difficulty sleeping for more than two weeks?",
#         "Have you lost interest in activities you used to enjoy?",
#         "Do you feel sad or depressed most of the time?",
#         '¿Ha tenido dificultades para dormir durante más de dos semanas?',
#         '¿Ha perdido el interés en actividades que solía disfrutar?',
#         '¿Se siente triste o deprimido la mayor parte del tiempo?',
#         '¿Tiene pensamientos negativos sobre usted mismo o el mundo?',
#         '¿Ha tenido problemas para concentrarse o recordar cosas?',
#         '¿Siente que se mueve más lento o que sus movimientos son torpes?',
#         '¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?',
#         '¿Se siente agitado o ansioso la mayor parte del tiempo?',
#         '¿Tiene problemas para conciliar el sueño o despertarse temprano?',
#         '¿Se siente irritable o fácilmente molesto?',
#         '¿Se siente fatigado o sin energía la mayor parte del tiempo?',
#         '¿Ha tenido problemas para controlar su impulso o comportamiento?',
#         '¿Se ha sentido inseguro o preocupado por su apariencia física?',
#         '¿Ha tenido problemas para relacionarse con los demás?',
#         '¿Se ha sentido como si estuviera observando su vida desde afuera?',
#         '¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?',
#         '¿Ha tenido un episodio de manía o hipomanía?',
#         '¿Ha tenido problemas con el abuso de sustancias o el alcohol?',
#         '¿Ha tenido problemas para seguir con sus responsabilidades diarias?',
#         '¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?',
#         '¿Ha pensado en buscar ayuda profesional para su salud mental?',
#         '¿Ha recibido tratamiento para su salud mental en el pasado?',
#         '¿Tiene antecedentes familiares de trastornos mentales?',
#         '¿Tiene otras condiciones médicas que podrían afectar su salud mental?',
#         '¿Toma algún medicamento que podría afectar su salud mental?',
#         '¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?',
#         '¿Ha tenido experiencias traumáticas en el pasado?',
#         '¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?',
#         '¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?',
#         '¿Está dispuesto a buscar ayuda profesional si es necesario?',
#         # ... (add the rest of the questions)
#     ]

#     answers = []
#     for question in questionnaire:
#         user_answer = input(question + " (yes/no): ").lower()
#         answers.append(user_answer)

#     # Perform sentiment analysis on the questionnaire responses
#     sentiment_result = perform_sentiment_analysis(answers)
#     print("Sentiment analysis result for the questionnaire: ", sentiment_result)

# # Process answers or take further actions based on the responses

# def chatbot_response(user_input):
#     response = respond(user_input)
#     print('Chatbot: ' + response)
#     return response

# def disclaimer():
#     print('Disclaimer: This chatbot is not a substitute for professional medical advice. It is intended to provide general information and support.')
#     print('If you are experiencing mental health symptoms, please seek professional help.')
#     print('This chatbot is not intended to diagnose, treat, or cure any mental health conditions.')
#     print('User data may be shared with third parties for the purpose of providing and improving the chatbot.')
#     print('If you are in crisis, please seek professional help immediately.')
#     print('You can contact the National Suicide Prevention Lifeline at 1-800-273-TALK (1-800-273-8255) or text "MHA" to 741741 to speak with a trained crisis counselor.')

# disclaimer()





# # while True:
# #     user_input = input('You: ')
# #     if user_input.lower() == 'quit':
# #         break
# #     chatbot_response(user_input)

# %%
# if any(greeting_pattern in user_input.lower() for greeting_pattern in initial_greeting_corpus):
#         initial_greeting()
#     elif any(questionnaire_pattern in user_input.lower() for questionnaire_pattern in questionnaire_corpus):
#         handle_questionnaire()
#     elif any(end_pattern in user_input.lower() for end_pattern in end_conversation_corpus):
#         print("Ending the conversation. Goodbye!")
# #         break

# %%
# while True:
#     user_input = input('You: ')
#     if user_input.lower() == 'quit':
#         break
#     chatbot_response(user_input)

# %% [markdown]
# Note that this is just a basic example, and you can further customize the chatbot by adding more intents, entities, and conversation flows, as well as incorporating more advanced natural language processing techniques.
#
# Additionally, make sure to handle any errors that may arise and to follow best practices for handling and storing user data.

# %% [markdown]
# To implement natural language processing (NLP) in a mental health chatbot using TensorFlow and relevant libraries, you can follow these steps:
#
#
# 1. Install TensorFlow and other required libraries, such as NLTK, SpaCy, and Transformers, using pip.
#
# 2. Preprocess the data by tokenizing, lowercasing, removing stop words, and lemmatizing the text.
#
# 3. Define the intents and entities for the chatbot, such as greetings, goodbyes, and mental health conditions.
#
# 4. Define the conversation flow for the chatbot using a function that takes in user input, preprocesses it, and generates a response based on the predicted token.
#
# 5. Add clear disclaimers and refer users to appropriate mental health resources if they indicate that they may be experiencing mental health symptoms.
#
# 6. Test the chatbot by interacting with it and handling any errors that may arise.
#
# Here is an example code that demonstrates how to build a mental health chatbot using TensorFlow and relevant libraries:

# %%
# Sources:
#  analyticsvidhya.com (1)
#  sloboda-studio.com (2)
#  handsonai.medium.com (3)
#  alishaarora56.medium.com (4)

# %%
# import tensorflow as tf
# import nltk
# import spacy
# import transformers
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
# from spacy.lang.en.stop_words import STOP_WORDS
# from transformers import AutoTokenizer, TFAutoModelForMaskedLM

# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('stopwords')

# nlp = spacy.load('en_core_web_sm')
# tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# model = TFAutoModelForMaskedLM.from_pretrained('bert-base-uncased')
# lemmatizer = WordNetLemmatizer()
# stop_words = set(stopwords.words('english'))

# # intents = [
# #     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey']},
# #     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
# #     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# # ]

# # entities = [
# #     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress']}
# # ]


# intents = [
#     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey', 'good morning/afternoon/evening', 'how do you do?', 'pleased to meet you', 'it is a pleasure to meet you', 'good to see you', 'howdy', 'what is up?', 'how is it going?','long time no see' ,'hey there','hey man' , 'hey girl','what is new?','how are you doing?', 'all right, mate?', 'howyasay', 'g day','hola', 'que tal', 'guten tag', 'blimey! It is you!', 'hello there! how are you today?', 'how are you doing today?','howdy doody', 'top of the morning to you', 'greetings']},
#     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
#     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# ]

# entities = [
#     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress', 'worry', 'burden', 'load', 'concern','weight', 'mild', 'severe', 'tightness', 'tension', 'ache', 'pain','strain', 'job stress', 'financial stress', 'relationship stress', 'exam stress', 'public speaking stress', 'at my wit is end','be on edge', 'be under a gun', 'crack under pressure', 'feel like i am going to explode', 'have a lot of my plate', 'lose sleep over something', 'pull an all-nighter', 'sweet the small stuff', 'take it one day at a  time','the pressure is on', 'under pressure', 'wrack my brain' ]}
# ]

# initial_greeting_corpus = [
#     'hi',
#     'hello',
#     'hey',
#     'greetings',
#     'good morning',
#     'good afternoon',
#     'good evening',
#     'welcome',
#     'start chat',
#     'begin conversation'
# ]

# questionnaire_corpus = [
#     'start test',
#     'begin test',
#     'start questionnaire',
#     'mental health test',
#     'assess my mood',
#     'check my feelings',
#     'evaluate my mental health',
#     'answer some questions'
# ]

# end_conversation_corpus = [
#     'quit',
#     'exit',
#     'goodbye',
#     'bye',
#     'see you later',
#     'end chat',
#     'finish conversation',
#     'stop chatting'
# ]

# def preprocess(text):
#     doc = nlp(text)
#     tokens = [token.lemma_.lower().strip() for token in doc if token.lemma_ != '-PRON-' and token.lemma_ not in stop_words]
#     return ' '.join(tokens)

# def respond(user_input):
#     user_input = preprocess(user_input)
#     input_ids = tokenizer.encode(user_input, return_tensors='tf')
#     masked_lm_outputs = model(input_ids)
#     predicted_token = tf.argmax(masked_lm_outputs[0][:, 1, :], axis=-1)
#     predicted_token = tokenizer.decode(predicted_token[0])

#     if predicted_token in ['hi', 'hello', 'hey']:
#         return 'Hello! How can I help you with your mental health today?'
#     elif predicted_token in ['bye', 'goodbye', 'see you later']:
#         return 'Goodbye! Take care.'
#     elif predicted_token.lower() == 'start test' or predicted_token.lower() == 'begin test' or predicted_token.lower() == 'start questionnaire':
#         return 'Sure, I can help you with that. Let\'s start with some questions about your mental health. Have you been feeling down, depressed, or hopeless?',
#     else:
#         return 'I\'m sorry, I didn\'t understand that. Can you please rephrase it?'

#         def handle_questionnaire():
#     print("Let's start the mental health questionnaire:")
#     questionnaire = [
#         "Have you had difficulty sleeping for more than two weeks?",
#         "Have you lost interest in activities you used to enjoy?",
#         "Do you feel sad or depressed most of the time?",
#         '¿Ha tenido dificultades para dormir durante más de dos semanas?',
#         '¿Ha perdido el interés en actividades que solía disfrutar?',
#         '¿Se siente triste o deprimido la mayor parte del tiempo?',
#         '¿Tiene pensamientos negativos sobre usted mismo o el mundo?',
#         '¿Ha tenido problemas para concentrarse o recordar cosas?',
#         '¿Siente que se mueve más lento o que sus movimientos son torpes?',
#         '¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?',
#         '¿Se siente agitado o ansioso la mayor parte del tiempo?',
#         '¿Tiene problemas para conciliar el sueño o despertarse temprano?',
#         '¿Se siente irritable o fácilmente molesto?',
#         '¿Se siente fatigado o sin energía la mayor parte del tiempo?',
#         '¿Ha tenido problemas para controlar su impulso o comportamiento?',
#         '¿Se ha sentido inseguro o preocupado por su apariencia física?',
#         '¿Ha tenido problemas para relacionarse con los demás?',
#         '¿Se ha sentido como si estuviera observando su vida desde afuera?',
#         '¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?',
#         '¿Ha tenido un episodio de manía o hipomanía?',
#         '¿Ha tenido problemas con el abuso de sustancias o el alcohol?',
#         '¿Ha tenido problemas para seguir con sus responsabilidades diarias?',
#         '¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?',
#         '¿Ha pensado en buscar ayuda profesional para su salud mental?',
#         '¿Ha recibido tratamiento para su salud mental en el pasado?',
#         '¿Tiene antecedentes familiares de trastornos mentales?',
#         '¿Tiene otras condiciones médicas que podrían afectar su salud mental?',
#         '¿Toma algún medicamento que podría afectar su salud mental?',
#         '¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?',
#         '¿Ha tenido experiencias traumáticas en el pasado?',
#         '¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?',
#         '¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?',
#         '¿Está dispuesto a buscar ayuda profesional si es necesario?',
#         # ... (add the rest of the questions)
#     ]

#     answers = []
#     for question in questionnaire:
#         user_answer = input(question + " (yes/no): ").lower()
#         answers.append(user_answer)

#    # Perform sentiment analysis on the questionnaire responses
#     sentiment_result = perform_sentiment_analysis(answers)
#     print("Sentiment analysis result for the questionnaire: ", sentiment_result)

#         # Process answers or take further actions based on the responses

# def chatbot_response(user_input):
#     response = respond(user_input)
#     print('Chatbot: ' + response)
#     return response

# def disclaimer():
#     print('Disclaimer: This chatbot is not a substitute for professional medical advice. It is intended to provide general information and support.')
#     print('If you are experiencing mental health symptoms, please seek professional help.')
#     print('This chatbot is not intended to diagnose, treat, or cure any mental health conditions.')
#     print('User data may be shared with third parties for the purpose of providing and improving the chatbot.')
#     print('If you are in crisis, please seek professional help immediately.')
#     print('You can contact the National Suicide Prevention Lifeline at 1-800-273-TALK (1-800-273-8255) or text "MHA" to 741741 to speak with a trained crisis counselor.')

# disclaimer()

# # while True:
# #     user_input = input('You: ')
# #     if user_input.lower() == 'quit':
# #         break
# #     chatbot_response(user_input)

# %%
# while True:
#     user_input = input('You: ')
#     if user_input.lower() == 'quit':
#         break
#     chatbot_response(user_input)

# %% [markdown]
# What are the steps to implement sentiment analysis in a chatbot?

# %%
# Sources:
# handsonai.medium.com (1)
# ai.plainenglish.io (2)
# analyticsvidhya.com (3)
# handsonai.medium.com (4)

# %% [markdown]
# To implement sentiment analysis in a chatbot using TensorFlow and relevant libraries, you can follow these steps:
#
# 1. Install TensorFlow and other required libraries, such as NLTK, SpaCy, and Transformers, using pip.
#
# 2. Preprocess the data by tokenizing, lowercasing, removing stop words, and lemmatizing the text.
#
# 3. Define the intents and entities for the chatbot, such as greetings, goodbyes, and mental health conditions.
#
# 4. Define the conversation flow for the chatbot using a function that takes in user input, preprocesses it, and generates a response based on the predicted sentiment.
#
# 5. Add clear disclaimers and refer users to appropriate mental health resources if they indicate that they may be experiencing mental health symptoms.
#
# 6. Train a sentiment analysis model using TensorFlow and relevant libraries, such as Keras or TensorFlow Addons.
#
# 7. Test the chatbot by interacting with it and handling any errors that may arise.

# %% [markdown]
# Note that this is just a basic example, and you can further customize the chatbot by adding more intents, entities, and conversation flows, as well as incorporating more advanced natural language processing techniques. Additionally, make sure to handle any errors that may arise and to follow best practices for handling and storing user data.
#
# Sources:
#
# analyticsvidhya.com
#
# sloboda-studio.com
#
# handsonai.medium.com
#
# alishaarora56.medium.com

# %%
# Here is an example code that demonstrates how to build a
# mental health chatbot using TensorFlow and relevant libraries
# with sentiment analysis:

# %%
# import tensorflow as tf
# import nltk
# import spacy
# import transformers
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
# from spacy.lang.en.stop_words import STOP_WORDS
# from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
# from tensorflow.keras.preprocessing.sequence import pad_sequences
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, GlobalMaxPooling1D

# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('stopwords')

# nlp = spacy.load('en_core_web_sm')
# tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# model = TFAutoModelForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
# lemmatizer = WordNetLemmatizer()
# stop_words = set(stopwords.words('english'))

# # intents = [
# #     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey']},
# #     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
# #     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# # ]

# # entities = [
# #     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress']}
# # ]


# intents = [
#     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey', 'good morning/afternoon/evening', 'how do you do?', 'pleased to meet you', 'it is a pleasure to meet you', 'good to see you', 'howdy', 'what is up?', 'how is it going?','long time no see' ,'hey there','hey man' , 'hey girl','what is new?','how are you doing?', 'all right, mate?', 'howyasay', 'g day','hola', 'que tal', 'guten tag', 'blimey! It is you!', 'hello there! how are you today?', 'how are you doing today?','howdy doody', 'top of the morning to you', 'greetings']},
#     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
#     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# ]

# entities = [
#     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress', 'worry', 'burden', 'load', 'concern','weight', 'mild', 'severe', 'tightness', 'tension', 'ache', 'pain','strain', 'job stress', 'financial stress', 'relationship stress', 'exam stress', 'public speaking stress', 'at my wit is end','be on edge', 'be under a gun', 'crack under pressure', 'feel like i am going to explode', 'have a lot of my plate', 'lose sleep over something', 'pull an all-nighter', 'sweet the small stuff', 'take it one day at a  time','the pressure is on', 'under pressure', 'wrack my brain' ]}
# ]

# initial_greeting_corpus = [
#     'hi',
#     'hello',
#     'hey',
#     'greetings',
#     'good morning',
#     'good afternoon',
#     'good evening',
#     'welcome',
#     'start chat',
#     'begin conversation'
# ]

# questionnaire_corpus = [
#     'start test',
#     'begin test',
#     'start questionnaire',
#     'mental health test',
#     'assess my mood',
#     'check my feelings',
#     'evaluate my mental health',
#     'answer some questions'
# ]

# end_conversation_corpus = [
#     'quit',
#     'exit',
#     'goodbye',
#     'bye',
#     'see you later',
#     'end chat',
#     'finish conversation',
#     'stop chatting'
# ]
# def preprocess(text):
#     doc = nlp(text)
#     tokens = [token.lemma_.lower().strip() for token in doc if token.lemma_ != '-PRON-' and token.lemma_ not in stop_words]
#     return ' '.join(tokens)

# def respond(user_input):
#     user_input = preprocess(user_input)
#     input_ids = tokenizer.encode(user_input, return_tensors='tf')
#     output = model(input_ids)
#     predicted_sentiment = tf.argmax(output[0], axis=-1)

#     if predicted_sentiment == 0:
#         return 'I am glad you are feeling positive today!'
#     elif predicted_sentiment == 1:
#         return 'I am sorry to hear that you are feeling neutral today. Can I help you with anything?'
#     else:
#         return 'I am sorry to hear that you are feeling negative today. Can I help you with anything?'

# def handle_questionnaire():
#     print("Let's start the mental health questionnaire:")
#     questionnaire = [
#         "Have you had difficulty sleeping for more than two weeks?",
#         "Have you lost interest in activities you used to enjoy?",
#         "Do you feel sad or depressed most of the time?",
#         '¿Ha tenido dificultades para dormir durante más de dos semanas?',
#         '¿Ha perdido el interés en actividades que solía disfrutar?',
#         '¿Se siente triste o deprimido la mayor parte del tiempo?',
#         '¿Tiene pensamientos negativos sobre usted mismo o el mundo?',
#         '¿Ha tenido problemas para concentrarse o recordar cosas?',
#         '¿Siente que se mueve más lento o que sus movimientos son torpes?',
#         '¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?',
#         '¿Se siente agitado o ansioso la mayor parte del tiempo?',
#         '¿Tiene problemas para conciliar el sueño o despertarse temprano?',
#         '¿Se siente irritable o fácilmente molesto?',
#         '¿Se siente fatigado o sin energía la mayor parte del tiempo?',
#         '¿Ha tenido problemas para controlar su impulso o comportamiento?',
#         '¿Se ha sentido inseguro o preocupado por su apariencia física?',
#         '¿Ha tenido problemas para relacionarse con los demás?',
#         '¿Se ha sentido como si estuviera observando su vida desde afuera?',
#         '¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?',
#         '¿Ha tenido un episodio de manía o hipomanía?',
#         '¿Ha tenido problemas con el abuso de sustancias o el alcohol?',
#         '¿Ha tenido problemas para seguir con sus responsabilidades diarias?',
#         '¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?',
#         '¿Ha pensado en buscar ayuda profesional para su salud mental?',
#         '¿Ha recibido tratamiento para su salud mental en el pasado?',
#         '¿Tiene antecedentes familiares de trastornos mentales?',
#         '¿Tiene otras condiciones médicas que podrían afectar su salud mental?',
#         '¿Toma algún medicamento que podría afectar su salud mental?',
#         '¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?',
#         '¿Ha tenido experiencias traumáticas en el pasado?',
#         '¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?',
#         '¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?',
#         '¿Está dispuesto a buscar ayuda profesional si es necesario?',
#         # ... (add the rest of the questions)
#     ]

#     answers = []
#     for question in questionnaire:
#         user_answer = input(question + " (yes/no): ").lower()
#         answers.append(user_answer)

#     # Perform sentiment analysis on the questionnaire responses
#     sentiment_result = perform_sentiment_analysis(answers)
#     print("Sentiment analysis result for the questionnaire: ", sentiment_result)

# # Process answers or take further actions based on the responses

# def chatbot_response(user_input):
#     response = respond(user_input)
#     print('Chatbot: ' + response)
#     return response

# def disclaimer():
#     print('Disclaimer: This chatbot is not a substitute for professional medical advice. It is intended to provide general information and support.')
#     print('If you are experiencing mental health symptoms, please seek professional help.')
#     print('This chatbot is not intended to diagnose, treat, or cure any mental health conditions.')
#     print('User data may be shared with third parties for the purpose of providing and improving the chatbot.')
#     print('If you are in crisis, please seek professional help immediately.')
#     print('You can contact the National Suicide Prevention Lifeline at 1-800-273-TALK (1-800-273-8255) or text "MHA" to 741741 to speak with a trained crisis counselor.')

# disclaimer()

# # while True:
# #     user_input = input('You: ')
# #     if user_input.lower() == 'quit':
# #         break
# #     chatbot_response(user_input)

# %%
# while True:
#     user_input = input('You: ')
#     if user_input.lower() == 'quit':
#         break
#     chatbot_response(user_input)

# %% [markdown]
# Certainly! Your code is already well-structured, but there are a few areas where you can make improvements for better performance and efficiency. Here are some suggestions:

# %%
# 1. Batch Processing:
# Instead of processing one user input at a time,
# you can batch multiple inputs together.
# This is particularly useful when using transformers like BERT,
# which are optimized for parallel processing.
# This can significantly speed up the inference process.

# %%
# def batch_preprocess(texts):
#     docs = list(nlp.pipe(texts))
#     tokens_list = [
#         [token.lemma_.lower().strip() for token in doc if token.lemma_ != '-PRON-' and token.lemma_ not in stop_words]
#         for doc in docs
#     ]
#     return [' '.join(tokens) for tokens in tokens_list]

# def batch_respond(user_inputs):
#     preprocessed_inputs = batch_preprocess(user_inputs)
#     input_ids = tokenizer.batch_encode_plus(preprocessed_inputs, return_tensors='tf', padding=True)['input_ids']
#     output = model(input_ids)
#     predicted_sentiments = tf.argmax(output.logits, axis=-1)

#     responses = []
#     for sentiment in predicted_sentiments.numpy():
#         if sentiment == 0:
#             responses.append('I am glad you are feeling positive today!')
#         elif sentiment == 1:
#             responses.append('I am sorry to hear that you are feeling neutral today. Can I help you with anything?')
#         else:
#             responses.append('I am sorry to hear that you are feeling negative today. Can I help you with anything?')

#     return responses


# def handle_questionnaire():
#     print("Let's start the mental health questionnaire:")
#     questionnaire = [
#         "Have you had difficulty sleeping for more than two weeks?",
#         "Have you lost interest in activities you used to enjoy?",
#         "Do you feel sad or depressed most of the time?",
#         '¿Ha tenido dificultades para dormir durante más de dos semanas?',
#         '¿Ha perdido el interés en actividades que solía disfrutar?',
#         '¿Se siente triste o deprimido la mayor parte del tiempo?',
#         '¿Tiene pensamientos negativos sobre usted mismo o el mundo?',
#         '¿Ha tenido problemas para concentrarse o recordar cosas?',
#         '¿Siente que se mueve más lento o que sus movimientos son torpes?',
#         '¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?',
#         '¿Se siente agitado o ansioso la mayor parte del tiempo?',
#         '¿Tiene problemas para conciliar el sueño o despertarse temprano?',
#         '¿Se siente irritable o fácilmente molesto?',
#         '¿Se siente fatigado o sin energía la mayor parte del tiempo?',
#         '¿Ha tenido problemas para controlar su impulso o comportamiento?',
#         '¿Se ha sentido inseguro o preocupado por su apariencia física?',
#         '¿Ha tenido problemas para relacionarse con los demás?',
#         '¿Se ha sentido como si estuviera observando su vida desde afuera?',
#         '¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?',
#         '¿Ha tenido un episodio de manía o hipomanía?',
#         '¿Ha tenido problemas con el abuso de sustancias o el alcohol?',
#         '¿Ha tenido problemas para seguir con sus responsabilidades diarias?',
#         '¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?',
#         '¿Ha pensado en buscar ayuda profesional para su salud mental?',
#         '¿Ha recibido tratamiento para su salud mental en el pasado?',
#         '¿Tiene antecedentes familiares de trastornos mentales?',
#         '¿Tiene otras condiciones médicas que podrían afectar su salud mental?',
#         '¿Toma algún medicamento que podría afectar su salud mental?',
#         '¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?',
#         '¿Ha tenido experiencias traumáticas en el pasado?',
#         '¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?',
#         '¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?',
#         '¿Está dispuesto a buscar ayuda profesional si es necesario?',
#         # ... (add the rest of the questions)
#     ]

#     answers = []
#     for question in questionnaire:
#         user_answer = input(question + " (yes/no): ").lower()
#         answers.append(user_answer)


#    # Perform sentiment analysis on the questionnaire responses
#     sentiment_result = perform_sentiment_analysis(answers)
#     print("Sentiment analysis result for the questionnaire: ", sentiment_result)

# # Process answers or take further actions based on the responses

# def batch_chatbot_response(user_inputs):
#     responses = batch_respond(user_inputs)
#     for i, response in enumerate(responses):
#         print(f'User {i+1}: {user_inputs[i]}')
#         print(f'Chatbot: {response}')
#     return responses

# %%
# if any(greeting_pattern in user_input.lower() for greeting_pattern in initial_greeting_corpus):
#         initial_greeting()
#     elif any(questionnaire_pattern in user_input.lower() for questionnaire_pattern in questionnaire_corpus):
#         handle_questionnaire()
#     elif any(end_pattern in user_input.lower() for end_pattern in end_conversation_corpus):
#         print("Ending the conversation. Goodbye!")
# #         break

# %%
#  import tensorflow as tf

# %%
# Now you can call batch_chatbot_response with a list
# of user inputs for more efficient processing.

# %%
# 2. Optimize Model Loading:
# Loading the BERT model and tokenizer for every user input
# can be computationally expensive. You can load these models
# once and reuse them.

# %%
# # Move these outside the functions
# tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# model = TFAutoModelForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)

# %%
# 3. Use GPU:
# If you have access to a GPU, you can move your
# model and data to the GPU for faster processing.
# TensorFlow will automatically use the GPU if available.

# %%
# # Move model to GPU
# if tf.test.is_gpu_available():
#     model = model.gpu()  # This is equivalent to `model = model.to('cuda')` in PyTorch

# %%
# # Make sure to adjust your code accordingly if you decide to use GPU.

# # Move model to GPU
# model = model.to('cuda')

# # Move input tensors to GPU
# input_ids = input_ids.to('cuda')

# %%
# I apologize for the confusion. It seems there was a mistake in my
# previous suggestion. In TensorFlow,
# you don't use the to method for moving models to GPU. Instead,
# you can use tf.device to specify the device on which the model
# should run. Here's the correct way to move the model to the GPU:

# %%
             # Move model to GPU
# if tf.test.is_gpu_available():
#     model = model.gpu()  # This is equivalent to `model = model.to('cuda')` in PyTorch

# %%
# This code checks if a GPU is available and then moves the model
# to the GPU if one is present. Make sure to import tf from TensorFlow
# at the beginning of your script if you haven't already.

# %%
# import tensorflow as tf

# %%
# 4. Handle Batch Size Dynamically:
# If you want to handle varying batch sizes, you can
# adjust the padding dynamically based on the maximum
# length of the input in the batch.

# %%
# These optimizations should help improve the performance of your chatbot.
# Remember to test and profile your code to measure the impact of these
# changes.

# %% [markdown]
# It looks like there's an issue with the code because the variable preprocessed_inputs is not defined in the scope where you are trying to use it. If you are encountering this error, you might not have defined preprocessed_inputs before using it.
#
# Ensure that you call batch_preprocess before attempting to use preprocessed_inputs. Here's a modified version of the batch processing function for clarity:

# %%
# def batch_chatbot_response(user_inputs):
#     preprocessed_inputs = batch_preprocess(user_inputs)
#     max_len = max(len(tokens.split()) for tokens in preprocessed_inputs)
#     input_ids = tokenizer.batch_encode_plus(preprocessed_inputs, return_tensors='tf', padding='max_length', max_length=max_len)['input_ids']

#     output = model(input_ids)
#     predicted_sentiments = tf.argmax(output.logits, axis=-1)

#     responses = []
#     for sentiment in predicted_sentiments.numpy():
#         if sentiment == 0:
#             responses.append('I am glad you are feeling positive today!')
#         elif sentiment == 1:
#             responses.append('I am sorry to hear that you are feeling neutral today. Can I help you with anything?')
#         else:
#             responses.append('I am sorry to hear that you are feeling negative today. Can I help you with anything?')


# def handle_questionnaire():
#     print("Let's start the mental health questionnaire:")
#     questionnaire = [
#         "Have you had difficulty sleeping for more than two weeks?",
#         "Have you lost interest in activities you used to enjoy?",
#         "Do you feel sad or depressed most of the time?",
#         '¿Ha tenido dificultades para dormir durante más de dos semanas?',
#         '¿Ha perdido el interés en actividades que solía disfrutar?',
#         '¿Se siente triste o deprimido la mayor parte del tiempo?',
#         '¿Tiene pensamientos negativos sobre usted mismo o el mundo?',
#         '¿Ha tenido problemas para concentrarse o recordar cosas?',
#         '¿Siente que se mueve más lento o que sus movimientos son torpes?',
#         '¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?',
#         '¿Se siente agitado o ansioso la mayor parte del tiempo?',
#         '¿Tiene problemas para conciliar el sueño o despertarse temprano?',
#         '¿Se siente irritable o fácilmente molesto?',
#         '¿Se siente fatigado o sin energía la mayor parte del tiempo?',
#         '¿Ha tenido problemas para controlar su impulso o comportamiento?',
#         '¿Se ha sentido inseguro o preocupado por su apariencia física?',
#         '¿Ha tenido problemas para relacionarse con los demás?',
#         '¿Se ha sentido como si estuviera observando su vida desde afuera?',
#         '¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?',
#         '¿Ha tenido un episodio de manía o hipomanía?',
#         '¿Ha tenido problemas con el abuso de sustancias o el alcohol?',
#         '¿Ha tenido problemas para seguir con sus responsabilidades diarias?',
#         '¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?',
#         '¿Ha pensado en buscar ayuda profesional para su salud mental?',
#         '¿Ha recibido tratamiento para su salud mental en el pasado?',
#         '¿Tiene antecedentes familiares de trastornos mentales?',
#         '¿Tiene otras condiciones médicas que podrían afectar su salud mental?',
#         '¿Toma algún medicamento que podría afectar su salud mental?',
#         '¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?',
#         '¿Ha tenido experiencias traumáticas en el pasado?',
#         '¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?',
#         '¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?',
#         '¿Está dispuesto a buscar ayuda profesional si es necesario?',
#         # ... (add the rest of the questions)
#     ]

#     answers = []
#     for question in questionnaire:
#         user_answer = input(question + " (yes/no): ").lower()
#         answers.append(user_answer)

# # Perform sentiment analysis on the questionnaire responses
#     sentiment_result = perform_sentiment_analysis(answers)
#     print("Sentiment analysis result for the questionnaire: ", sentiment_result)

# # Process answers or take further actions based on the responses

#     for i, response in enumerate(responses):
#         print(f'User {i+1}: {user_inputs[i]}')
#         print(f'Chatbot: {response}')

#     return responses

# %%
# if any(greeting_pattern in user_input.lower() for greeting_pattern in initial_greeting_corpus):
#         initial_greeting()
#     elif any(questionnaire_pattern in user_input.lower() for questionnaire_pattern in questionnaire_corpus):
#         handle_questionnaire()
#     elif any(end_pattern in user_input.lower() for end_pattern in end_conversation_corpus):
#         print("Ending the conversation. Goodbye!")
# #         break

# %%
# max_len = max(len(tokens) for tokens in preprocessed_inputs)
# input_ids = tokenizer.batch_encode_plus(preprocessed_inputs, return_tensors='tf', padding='max_length', max_length=max_len)['input_ids']

# %%
# In the provided code, the conversation is initiated through the
# while loop that continuously prompts the user for input until
# they type "quit." However, if you want to provide a more interactive
# and user-friendly start to the conversation, you can modify
# the code to include an initial greeting or prompt from the chatbot.

# Here's an updated version of the code with an initial greeting:

# %%
# import tensorflow as tf
# import nltk
# import spacy
# import transformers
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
# from spacy.lang.en.stop_words import STOP_WORDS
# from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
# from tensorflow.keras.preprocessing.sequence import pad_sequences
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, GlobalMaxPooling1D

# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('stopwords')

# nlp = spacy.load('en_core_web_sm')
# tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# model = TFAutoModelForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
# lemmatizer = WordNetLemmatizer()
# stop_words = set(stopwords.words('english'))

# # intents = [
# #     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey']},
# #     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
# #     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# # ]

# # entities = [
# #     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress']}
# # ]


# intents = [
#     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey', 'good morning/afternoon/evening', 'how do you do?', 'pleased to meet you', 'it is a pleasure to meet you', 'good to see you', 'howdy', 'what is up?', 'how is it going?','long time no see' ,'hey there','hey man' , 'hey girl','what is new?','how are you doing?', 'all right, mate?', 'howyasay', 'g day','hola', 'que tal', 'guten tag', 'blimey! It is you!', 'hello there! how are you today?', 'how are you doing today?','howdy doody', 'top of the morning to you', 'greetings']},
#     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
#     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# ]

# entities = [
#     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress', 'worry', 'burden', 'load', 'concern','weight', 'mild', 'severe', 'tightness', 'tension', 'ache', 'pain','strain', 'job stress', 'financial stress', 'relationship stress', 'exam stress', 'public speaking stress', 'at my wit is end','be on edge', 'be under a gun', 'crack under pressure', 'feel like i am going to explode', 'have a lot of my plate', 'lose sleep over something', 'pull an all-nighter', 'sweet the small stuff', 'take it one day at a  time','the pressure is on', 'under pressure', 'wrack my brain' ]}
# ]

# initial_greeting_corpus = [
#     'hi',
#     'hello',
#     'hey',
#     'greetings',
#     'good morning',
#     'good afternoon',
#     'good evening',
#     'welcome',
#     'start chat',
#     'begin conversation'
# ]

# questionnaire_corpus = [
#     'start test',
#     'begin test',
#     'start questionnaire',
#     'mental health test',
#     'assess my mood',
#     'check my feelings',
#     'evaluate my mental health',
#     'answer some questions'
# ]

# end_conversation_corpus = [
#     'quit',
#     'exit',
#     'goodbye',
#     'bye',
#     'see you later',
#     'end chat',
#     'finish conversation',
#     'stop chatting'
# ]

# def preprocess(text):
#     doc = nlp(text)
#     tokens = [token.lemma_.lower().strip() for token in doc if token.lemma_ != '-PRON-' and token.lemma_ not in stop_words]
#     return ' '.join(tokens)

# def respond(user_input):
#     user_input = preprocess(user_input)
#     input_ids = tokenizer.encode(user_input, return_tensors='tf')
#     output = model(input_ids)
#     predicted_sentiment = tf.argmax(output[0], axis=-1)

#     if predicted_sentiment == 0:
#         return 'I am glad you are feeling positive today!'
#     elif predicted_sentiment == 1:
#         return 'I am sorry to hear that you are feeling neutral today. Can I help you with anything?'
#     else:
#         return 'I am sorry to hear that you are feeling negative today. Can I help you with anything?'


#         def handle_questionnaire():
#     print("Let's start the mental health questionnaire:")
#     questionnaire = [
#         "Have you had difficulty sleeping for more than two weeks?",
#         "Have you lost interest in activities you used to enjoy?",
#         "Do you feel sad or depressed most of the time?",
#         '¿Ha tenido dificultades para dormir durante más de dos semanas?',
#         '¿Ha perdido el interés en actividades que solía disfrutar?',
#         '¿Se siente triste o deprimido la mayor parte del tiempo?',
#         '¿Tiene pensamientos negativos sobre usted mismo o el mundo?',
#         '¿Ha tenido problemas para concentrarse o recordar cosas?',
#         '¿Siente que se mueve más lento o que sus movimientos son torpes?',
#         '¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?',
#         '¿Se siente agitado o ansioso la mayor parte del tiempo?',
#         '¿Tiene problemas para conciliar el sueño o despertarse temprano?',
#         '¿Se siente irritable o fácilmente molesto?',
#         '¿Se siente fatigado o sin energía la mayor parte del tiempo?',
#         '¿Ha tenido problemas para controlar su impulso o comportamiento?',
#         '¿Se ha sentido inseguro o preocupado por su apariencia física?',
#         '¿Ha tenido problemas para relacionarse con los demás?',
#         '¿Se ha sentido como si estuviera observando su vida desde afuera?',
#         '¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?',
#         '¿Ha tenido un episodio de manía o hipomanía?',
#         '¿Ha tenido problemas con el abuso de sustancias o el alcohol?',
#         '¿Ha tenido problemas para seguir con sus responsabilidades diarias?',
#         '¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?',
#         '¿Ha pensado en buscar ayuda profesional para su salud mental?',
#         '¿Ha recibido tratamiento para su salud mental en el pasado?',
#         '¿Tiene antecedentes familiares de trastornos mentales?',
#         '¿Tiene otras condiciones médicas que podrían afectar su salud mental?',
#         '¿Toma algún medicamento que podría afectar su salud mental?',
#         '¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?',
#         '¿Ha tenido experiencias traumáticas en el pasado?',
#         '¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?',
#         '¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?',
#         '¿Está dispuesto a buscar ayuda profesional si es necesario?',
#         # ... (add the rest of the questions)
#     ]

#     answers = []
#     for question in questionnaire:
#         user_answer = input(question + " (yes/no): ").lower()
#         answers.append(user_answer)

# # Perform sentiment analysis on the questionnaire responses
#     sentiment_result = perform_sentiment_analysis(answers)
#     print("Sentiment analysis result for the questionnaire: ", sentiment_result)

# # Process answers or take further actions based on the responses

# def chatbot_response(user_input):
#     response = respond(user_input)
#     print('Chatbot: ' + response)
#     return response

# def disclaimer():
#     print('Disclaimer: This chatbot is not a substitute for professional medical advice. It is intended to provide general information and support.')
#     print('If you are experiencing mental health symptoms, please seek professional help.')
#     print('This chatbot is not intended to diagnose, treat, or cure any mental health conditions.')
#     print('User data may be shared with third parties for the purpose of providing and improving the chatbot.')
#     print('If you are in crisis, please seek professional help immediately.')
#     print('You can contact the National Suicide Prevention Lifeline at 1-800-273-TALK (1-800-273-8255) or text "MHA" to 741741 to speak with a trained crisis counselor.')

# def initial_greeting():
#     print("Welcome to the Mental Health Chatbot!")
#     print("I'm here to provide information and support. You can type 'quit' at any time to exit the chat.")
#     print("How can I assist you today?")

# disclaimer()
# initial_greeting()

# # while True:
# #     user_input = input('You: ')
# #     if user_input.lower() == 'quit':
# #         break
# #     chatbot_response(user_input)

# %%
# if any(greeting_pattern in user_input.lower() for greeting_pattern in initial_greeting_corpus):
#         initial_greeting()
#     elif any(questionnaire_pattern in user_input.lower() for questionnaire_pattern in questionnaire_corpus):
#         handle_questionnaire()
#     elif any(end_pattern in user_input.lower() for end_pattern in end_conversation_corpus):
#         print("Ending the conversation. Goodbye!")
# #         break

# %%
# This modified code includes an initial_greeting function
# that is called at the beginning of the conversation.
# The chatbot will start with a welcoming message,
# providing some information about its purpose and how the user
# can interact with it. The user can then respond with their
# input to continue the conversation.

# %%
# while True:
#     user_input = input('You: ')
#     if user_input.lower() == 'quit':
#         break
#     chatbot_response(user_input)

# %% [markdown]
# User:
#
# Can you advise me with a corpus of an initial greeting a corpus during the questionnaire and the end of the conversation?
#
# ChatGPT:
#
# Certainly! Creating a corpus for different parts of the conversation involves defining patterns or phrases that the chatbot can recognize.
#
# Below are examples of potential corpora for the initial greeting, during the questionnaire, and the end of the conversation:

# %%
# import tensorflow as tf
# import nltk
# import spacy
# import transformers
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
# from spacy.lang.en.stop_words import STOP_WORDS
# from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
# from tensorflow.keras.preprocessing.sequence import pad_sequences
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, GlobalMaxPooling1D

# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('stopwords')

# nlp = spacy.load('en_core_web_sm')
# tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# model = TFAutoModelForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
# lemmatizer = WordNetLemmatizer()
# stop_words = set(stopwords.words('english'))

# %%
# intents = [
#      {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey', 'good morning/afternoon/evening', 'how do you do?', 'pleased to meet you', 'it is a pleasure to meet you', 'good to see you', 'howdy', 'what is up?', 'how is it going?','long time no see' ,'hey there','hey man' , 'hey girl','what is new?','how are you doing?', 'all right, mate?', 'howyasay', 'g day','hola', 'que tal', 'guten tag', 'blimey! It is you!', 'hello there! how are you today?', 'how are you doing today?','howdy doody', 'top of the morning to you', 'greetings']},
#      {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
#      {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
#  ]

#  entities = [
#      {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress', 'worry', 'burden', 'load', 'concern','weight', 'mild', 'severe', 'tightness', 'tension', 'ache', 'pain','strain', 'job stress', 'financial stress', 'relationship stress', 'exam stress', 'public speaking stress', 'at my wit is end','be on edge', 'be under a gun', 'crack under pressure', 'feel like i am going to explode', 'have a lot of my plate', 'lose sleep over something', 'pull an all-nighter', 'sweet the small stuff', 'take it one day at a  time','the pressure is on', 'under pressure', 'wrack my brain' ]}
#  ]

#  initial_greeting_corpus = [
#      'hi',
# #     'hello',
#     'hey',
#     'greetings',
#     'good morning',
#     'good afternoon',
#     'good evening',
#     'welcome',
#     'start chat',
#     'begin conversation'
# ]

# questionnaire_corpus = [
#     'start test',
#     'begin test',
#     'start questionnaire',
#     'mental health test',
#     'assess my mood',
#     'check my feelings',
#     'evaluate my mental health',
#     'answer some questions'
# ]

# end_conversation_corpus = [
#     'quit',
#     'exit',
#     'goodbye',
#     'bye',
#     'see you later',
#     'end chat',
#     'finish conversation',
#     'stop chatting'
# ]

# %%
# initial_greeting_corpus = [
#     'hi',
#     'hello',
#     'hey',
#     'greetings',
#     'good morning',
#     'good afternoon',
#     'good evening',
#     'welcome',
#     'start chat',
#     'begin conversation'
# ]

# %%
# questionnaire_corpus = [
#     'start test',
#     'begin test',
#     'start questionnaire',
#     'mental health test',
#     'assess my mood',
#     'check my feelings',
#     'evaluate my mental health',
#     'answer some questions'
# ]

# %%
# end_conversation_corpus = [
#     'quit',
#     'exit',
#     'goodbye',
#     'bye',
#     'see you later',
#     'end chat',
#     'finish conversation',
#     'stop chatting'
# ]

# %%
# def preprocess(text):
#     doc = nlp(text)
#     tokens = [token.lemma_.lower().strip() for token in doc if token.lemma_ != '-PRON-' and token.lemma_ not in stop_words]
#     return ' '.join(tokens)

# def respond(user_input):
#     user_input = preprocess(user_input)
#     input_ids = tokenizer.encode(user_input, return_tensors='tf')
#     output = model(input_ids)
#     predicted_sentiment = tf.argmax(output[0], axis=-1)

#     if predicted_sentiment == 0:
#         return 'I am glad you are feeling positive today!'
#     elif predicted_sentiment == 1:
#         return 'I am sorry to hear that you are feeling neutral today. Can I help you with anything?'
#     else:
#         return 'I am sorry to hear that you are feeling negative today. Can I help you with anything?'

# def handle_questionnaire():
#     print("Let's start the mental health questionnaire:")
#     questionnaire = [
#         'Have you had difficulty sleeping for more than two weeks?',
#         'Have you lost interest in activities you used to enjoy?',
#         'Do you feel sad or depressed most of the time?',
#         '¿Ha tenido dificultades para dormir durante más de dos semanas?',
#         '¿Ha perdido el interés en actividades que solía disfrutar?',
#         '¿Se siente triste o deprimido la mayor parte del tiempo?',
#         '¿Tiene pensamientos negativos sobre usted mismo o el mundo?',
#         '¿Ha tenido problemas para concentrarse o recordar cosas?',
#         '¿Siente que se mueve más lento o que sus movimientos son torpes?',
#         '¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?',
#         '¿Se siente agitado o ansioso la mayor parte del tiempo?',
#         '¿Tiene problemas para conciliar el sueño o despertarse temprano?',
#         '¿Se siente irritable o fácilmente molesto?',
#         '¿Se siente fatigado o sin energía la mayor parte del tiempo?',
#         '¿Ha tenido problemas para controlar su impulso o comportamiento?',
#         '¿Se ha sentido inseguro o preocupado por su apariencia física?',
#         '¿Ha tenido problemas para relacionarse con los demás?',
#         '¿Se ha sentido como si estuviera observando su vida desde afuera?',
#         '¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?',
#         '¿Ha tenido un episodio de manía o hipomanía?',
#         '¿Ha tenido problemas con el abuso de sustancias o el alcohol?',
#         '¿Ha tenido problemas para seguir con sus responsabilidades diarias?',
#         '¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?',
#         '¿Ha pensado en buscar ayuda profesional para su salud mental?',
#         '¿Ha recibido tratamiento para su salud mental en el pasado?',
#         '¿Tiene antecedentes familiares de trastornos mentales?',
#         '¿Tiene otras condiciones médicas que podrían afectar su salud mental?',
#         '¿Toma algún medicamento que podría afectar su salud mental?',
#         '¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?',
#         '¿Ha tenido experiencias traumáticas en el pasado?',
#         '¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?',
#         '¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?',
#         '¿Está dispuesto a buscar ayuda profesional si es necesario?',
#         # ... (add the rest of the questions)
#     ]

#     answers = []
#     for question in questionnaire:
#         user_answer = input(question + " (yes/no): ").lower()
#         answers.append(user_answer)

# # Perform sentiment analysis on the questionnaire responses
#     sentiment_result = perform_sentiment_analysis(answers)
#     print("Sentiment analysis result for the questionnaire: ", sentiment_result)

#     # Process answers or take further actions based on the responses

# def chatbot_response(user_input):
#     response = respond(user_input)
#     print('Chatbot: ' + response)

#     if any(intent['patterns'][0] in user_input.lower() for intent in intents):
#         handle_questionnaire()

# def disclaimer():
#     print('Disclaimer: This chatbot is not a substitute for professional medical advice. It is intended to provide general information and support.')
#     print('If you are experiencing mental health symptoms, please seek professional help.')
#     print('This chatbot is not intended to diagnose, treat, or cure any mental health conditions.')
#     print('User data may be shared with third parties for the purpose of providing and improving the chatbot.')
#     print('If you are in crisis, please seek professional help immediately.')
#     print('You can contact the National Suicide Prevention Lifeline at 1-800-273-TALK (1-800-273-8255) or text "MHA" to 741741 to speak with a trained crisis counselor.')

# def initial_greeting():
#     print("Welcome to the Mental Health Chatbot!")
#     print("I'm here to provide information and support. You can type 'quit' at any time to exit the chat.")
#     print("How can I assist you today?")

# disclaimer()
# initial_greeting()

# # while True:
# #     user_input = input('You: ')
# #     if user_input.lower() == 'quit':
# #         break
# #     chatbot_response(user_input)

# %%
# You can use these corpora in your code to check if the user
# input matches any of the predefined patterns for each
# specific part of the conversation. For example, you might
# modify the while loop to include logic like this:

# %%
# while True:
#     user_input = input('You: ')

#     if any(greeting_pattern in user_input.lower() for greeting_pattern in initial_greeting_corpus):
#         initial_greeting()
#     elif any(questionnaire_pattern in user_input.lower() for questionnaire_pattern in questionnaire_corpus):
#         # Logic for handling questionnaire
#         print("Starting the questionnaire...")
#     elif any(end_pattern in user_input.lower() for end_pattern in end_conversation_corpus):
#         print("Ending the conversation. Goodbye!")
#         break
#     else:
#         chatbot_response(user_input)

# %% [markdown]
# User:
#
# How can I integrate this questionnaire in this code in Python with colab with all TensorFlow libraries:
#
# ¿Ha tenido dificultades para dormir durante más de dos semanas?
#
# ¿Ha perdido el interés en actividades que solía disfrutar?
#
# ¿Se siente triste o deprimido la mayor parte del tiempo?
#
# ¿Tiene pensamientos negativos sobre usted mismo o el mundo?
#
# ¿Ha tenido problemas para concentrarse o recordar cosas?
#
# ¿Siente que se mueve más lento o que sus movimientos son torpes?
#
# ¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?
#
# ¿Se siente agitado o ansioso la mayor parte del tiempo?
#
# ¿Tiene problemas para conciliar el sueño o despertarse temprano?
#
# ¿Se siente irritable o fácilmente molesto?
#
# ¿Se siente fatigado o sin energía la mayor parte del tiempo?
#
# ¿Ha tenido problemas para controlar su impulso o comportamiento?
#
# ¿Se ha sentido inseguro o preocupado por su apariencia física?
#
# ¿Ha tenido problemas para relacionarse con los demás?
#
# ¿Se ha sentido como si estuviera observando su vida desde afuera?
#
# ¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?
#
# ¿Ha tenido un episodio de manía o hipomanía?
#
# ¿Ha tenido problemas con el abuso de sustancias o el alcohol?
#
# ¿Ha tenido problemas para seguir con sus responsabilidades diarias?
#
# ¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?
#
# ¿Ha pensado en buscar ayuda profesional para su salud mental?
#
# ¿Ha recibido tratamiento para su salud mental en el pasado?
#
# ¿Tiene antecedentes familiares de trastornos mentales?
#
# ¿Tiene otras condiciones médicas que podrían afectar su salud mental?
#
# ¿Toma algún medicamento que podría afectar su salud mental?
#
# ¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?
#
# ¿Ha tenido experiencias traumáticas en el pasado?
#
# ¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?
#
# ¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?
#
# ¿Está dispuesto a buscar ayuda profesional si es necesario?

# %% [markdown]
# To integrate the provided questionnaire in your code, you can extend the existing functionality.
#
# Here's an updated version of your code that includes the questionnaire. Note that I've translated the questions into English for consistency with the rest of the code:

# %%
# import tensorflow as tf
# import nltk
# import spacy
# import transformers
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
# from spacy.lang.en.stop_words import STOP_WORDS
# from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
# from tensorflow.keras.preprocessing.sequence import pad_sequences
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, GlobalMaxPooling1D

# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('stopwords')

# nlp = spacy.load('en_core_web_sm')
# tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# model = TFAutoModelForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
# lemmatizer = WordNetLemmatizer()
# stop_words = set(stopwords.words('english'))

# # intents = [
# #     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey']},
# #     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
# #     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# # ]

# # entities = [
# #     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress']}
# # ]

# intents = [
#     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey', 'good morning/afternoon/evening', 'how do you do?', 'pleased to meet you', 'it is a pleasure to meet you', 'good to see you', 'howdy', 'what is up?', 'how is it going?','long time no see' ,'hey there','hey man' , 'hey girl','what is new?','how are you doing?', 'all right, mate?', 'howyasay', 'g day','hola', 'que tal', 'guten tag', 'blimey! It is you!', 'hello there! how are you today?', 'how are you doing today?','howdy doody', 'top of the morning to you', 'greetings']},
#     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
#     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# ]

# entities = [
#     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress', 'worry', 'burden', 'load', 'concern','weight', 'mild', 'severe', 'tightness', 'tension', 'ache', 'pain','strain', 'job stress', 'financial stress', 'relationship stress', 'exam stress', 'public speaking stress', 'at my wit is end','be on edge', 'be under a gun', 'crack under pressure', 'feel like i am going to explode', 'have a lot of my plate', 'lose sleep over something', 'pull an all-nighter', 'sweet the small stuff', 'take it one day at a  time','the pressure is on', 'under pressure', 'wrack my brain' ]}
# ]

# initial_greeting_corpus = [
#     'hi',
#     'hello',
#     'hey',
#     'greetings',
#     'good morning',
#     'good afternoon',
#     'good evening',
#     'welcome',
#     'start chat',
#     'begin conversation'
# ]

# questionnaire_corpus = [
#     'start test',
#     'begin test',
#     'start questionnaire',
#     'mental health test',
#     'assess my mood',
#     'check my feelings',
#     'evaluate my mental health',
#     'answer some questions'
# ]

# end_conversation_corpus = [
#     'quit',
#     'exit',
#     'goodbye',
#     'bye',
#     'see you later',
#     'end chat',
#     'finish conversation',
#     'stop chatting'
# ]

# def preprocess(text):
#     doc = nlp(text)
#     tokens = [token.lemma_.lower().strip() for token in doc if token.lemma_ != '-PRON-' and token.lemma_ not in stop_words]
#     return ' '.join(tokens)

# def respond(user_input):
#     user_input = preprocess(user_input)
#     input_ids = tokenizer.encode(user_input, return_tensors='tf')
#     output = model(input_ids)
#     predicted_sentiment = tf.argmax(output[0], axis=-1)

#     if predicted_sentiment == 0:
#         return 'I am glad you are feeling positive today!'
#     elif predicted_sentiment == 1:
#         return 'I am sorry to hear that you are feeling neutral today. Can I help you with anything?'
#     else:
#         return 'I am sorry to hear that you are feeling negative today. Can I help you with anything?'

# def handle_questionnaire():
#     print("Let's start the mental health questionnaire:")
#     questionnaire = [
#         'Have you had difficulty sleeping for more than two weeks?',
#         'Have you lost interest in activities you used to enjoy?',
#         'Do you feel sad or depressed most of the time?',
#         '¿Ha tenido dificultades para dormir durante más de dos semanas?',
#         '¿Ha perdido el interés en actividades que solía disfrutar?',
#         '¿Se siente triste o deprimido la mayor parte del tiempo?',
#         '¿Tiene pensamientos negativos sobre usted mismo o el mundo?',
#         '¿Ha tenido problemas para concentrarse o recordar cosas?',
#         '¿Siente que se mueve más lento o que sus movimientos son torpes?',
#         '¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?',
#         '¿Se siente agitado o ansioso la mayor parte del tiempo?',
#         '¿Tiene problemas para conciliar el sueño o despertarse temprano?',
#         '¿Se siente irritable o fácilmente molesto?',
#         '¿Se siente fatigado o sin energía la mayor parte del tiempo?',
#         '¿Ha tenido problemas para controlar su impulso o comportamiento?',
#         '¿Se ha sentido inseguro o preocupado por su apariencia física?',
#         '¿Ha tenido problemas para relacionarse con los demás?',
#         '¿Se ha sentido como si estuviera observando su vida desde afuera?',
#         '¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?',
#         '¿Ha tenido un episodio de manía o hipomanía?',
#         '¿Ha tenido problemas con el abuso de sustancias o el alcohol?',
#         '¿Ha tenido problemas para seguir con sus responsabilidades diarias?',
#         '¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?',
#         '¿Ha pensado en buscar ayuda profesional para su salud mental?',
#         '¿Ha recibido tratamiento para su salud mental en el pasado?',
#         '¿Tiene antecedentes familiares de trastornos mentales?',
#         '¿Tiene otras condiciones médicas que podrían afectar su salud mental?',
#         '¿Toma algún medicamento que podría afectar su salud mental?',
#         '¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?',
#         '¿Ha tenido experiencias traumáticas en el pasado?',
#         '¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?',
#         '¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?',
#         '¿Está dispuesto a buscar ayuda profesional si es necesario?',
#         # ... (add the rest of the questions)
#     ]

#     answers = []
#     for question in questionnaire:
#         user_answer = input(question + " (yes/no): ").lower()
#         answers.append(user_answer)

# # Perform sentiment analysis on the questionnaire responses
#     sentiment_result = perform_sentiment_analysis(answers)
#     print("Sentiment analysis result for the questionnaire: ", sentiment_result)

#     # Process answers or take further actions based on the responses

# def chatbot_response(user_input):
#     response = respond(user_input)
#     print('Chatbot: ' + response)

#     if any(intent['patterns'][0] in user_input.lower() for intent in intents):
#         handle_questionnaire()

# def disclaimer():
#     print('Disclaimer: This chatbot is not a substitute for professional medical advice. It is intended to provide general information and support.')
#     print('If you are experiencing mental health symptoms, please seek professional help.')
#     print('This chatbot is not intended to diagnose, treat, or cure any mental health conditions.')
#     print('User data may be shared with third parties for the purpose of providing and improving the chatbot.')
#     print('If you are in crisis, please seek professional help immediately.')
#     print('You can contact the National Suicide Prevention Lifeline at 1-800-273-TALK (1-800-273-8255) or text "MHA" to 741741 to speak with a trained crisis counselor.')

# def initial_greeting():
#     print("Welcome to the Mental Health Chatbot!")
#     print("I'm here to provide information and support. You can type 'quit' at any time to exit the chat.")
#     print("How can I assist you today?")

# disclaimer()
# initial_greeting()

# # while True:
# #     user_input = input('You: ')
# #     if user_input.lower() == 'quit':
# #         break
# #     chatbot_response(user_input)

# %%
# if any(greeting_pattern in user_input.lower() for greeting_pattern in initial_greeting_corpus):
#         initial_greeting()
#     elif any(questionnaire_pattern in user_input.lower() for questionnaire_pattern in questionnaire_corpus):
#         handle_questionnaire()
#     elif any(end_pattern in user_input.lower() for end_pattern in end_conversation_corpus):
#         print("Ending the conversation. Goodbye!")
# #         break

# %%
# while True:
#     user_input = input('You: ')
#     if user_input.lower() == 'quit':
#         break
#     chatbot_response(user_input)

# %%
#  Certainly! You can integrate the provided corpora into the modified code as follows:

# %%
#  Now, the code includes the integration of the initial_greeting_corpus,
#  questionnaire_corpus, and end_conversation_corpus into
#  the chatbot logic, allowing the chatbot to respond appropriately
#  based on the user's input.

# %%
import tensorflow as tf
import nltk
import spacy
import transformers
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from spacy.lang.en.stop_words import STOP_WORDS
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, GlobalMaxPooling1D

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

nlp = spacy.load('en_core_web_sm')
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
model = TFAutoModelForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# intents = [
#     {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey']},
#     {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
#     {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
# ]

# entities = [
#     {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress']}
# ]

intents = [
    {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey', 'good morning/afternoon/evening', 'how do you do?', 'pleased to meet you', 'it is a pleasure to meet you', 'good to see you', 'howdy', 'what is up?', 'how is it going?','long time no see' ,'hey there','hey man' , 'hey girl','what is new?','how are you doing?', 'all right, mate?', 'howyasay', 'g day','hola', 'que tal', 'guten tag', 'blimey! It is you!', 'hello there! how are you today?', 'how are you doing today?','howdy doody', 'top of the morning to you', 'greetings']},
    {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
    {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
]

entities = [
    {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress', 'worry', 'burden', 'load', 'concern','weight', 'mild', 'severe', 'tightness', 'tension', 'ache', 'pain','strain', 'job stress', 'financial stress', 'relationship stress', 'exam stress', 'public speaking stress', 'at my wit is end','be on edge', 'be under a gun', 'crack under pressure', 'feel like i am going to explode', 'have a lot of my plate', 'lose sleep over something', 'pull an all-nighter', 'sweet the small stuff', 'take it one day at a  time','the pressure is on', 'under pressure', 'wrack my brain' ]}
]

initial_greeting_corpus = [
    'hi',
    'hello',
    'hey',
    'greetings',
    'good morning',
    'good afternoon',
    'good evening',
    'welcome',
    'start chat',
    'begin conversation'
]

questionnaire_corpus = [
    'start test',
    'begin test',
    'start questionnaire',
    'mental health test',
    'assess my mood',
    'check my feelings',
    'evaluate my mental health',
    'answer some questions'
]

end_conversation_corpus = [
    'quit',
    'exit',
    'goodbye',
    'bye',
    'see you later',
    'end chat',
    'finish conversation',
    'stop chatting'
]

initial_greeting_corpus = [
    'hi',
    'hello',
    'hey',
    'greetings',
    'good morning',
    'good afternoon',
    'good evening',
    'welcome',
    'start chat',
    'begin conversation'
]

questionnaire_corpus = [
    'start test',
    'begin test',
    'start questionnaire',
    'mental health test',
    'assess my mood',
    'check my feelings',
    'evaluate my mental health',
    'answer some questions'
]

end_conversation_corpus = [
    'quit',
    'exit',
    'goodbye',
    'bye',
    'see you later',
    'end chat',
    'finish conversation',
    'stop chatting'
]

def preprocess(text):
    doc = nlp(text)
    tokens = [token.lemma_.lower().strip() for token in doc if token.lemma_ != '-PRON-' and token.lemma_ not in stop_words]
    return ' '.join(tokens)

def respond(user_input):
    user_input = preprocess(user_input)
    input_ids = tokenizer.encode(user_input, return_tensors='tf')
    output = model(input_ids)
    predicted_sentiment = tf.argmax(output[0], axis=-1)

    if predicted_sentiment == 0:
        return 'I am glad you are feeling positive today!'
    elif predicted_sentiment == 1:
        return 'I am sorry to hear that you are feeling neutral today. Can I help you with anything?'
    else:
        return 'I am sorry to hear that you are feeling negative today. Can I help you with anything?'

def handle_questionnaire():
    print("Let's start the mental health questionnaire:")
    questionnaire = [
        "Have you had difficulty sleeping for more than two weeks?",
        "Have you lost interest in activities you used to enjoy?",
        "Do you feel sad or depressed most of the time?",
        '¿Ha tenido dificultades para dormir durante más de dos semanas?',
        '¿Ha perdido el interés en actividades que solía disfrutar?',
        '¿Se siente triste o deprimido la mayor parte del tiempo?',
        '¿Tiene pensamientos negativos sobre usted mismo o el mundo?',
        '¿Ha tenido problemas para concentrarse o recordar cosas?',
        '¿Siente que se mueve más lento o que sus movimientos son torpes?',
        '¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?',
        '¿Se siente agitado o ansioso la mayor parte del tiempo?',
        '¿Tiene problemas para conciliar el sueño o despertarse temprano?',
        '¿Se siente irritable o fácilmente molesto?',
        '¿Se siente fatigado o sin energía la mayor parte del tiempo?',
        '¿Ha tenido problemas para controlar su impulso o comportamiento?',
        '¿Se ha sentido inseguro o preocupado por su apariencia física?',
        '¿Ha tenido problemas para relacionarse con los demás?',
        '¿Se ha sentido como si estuviera observando su vida desde afuera?',
        '¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?',
        '¿Ha tenido un episodio de manía o hipomanía?',
        '¿Ha tenido problemas con el abuso de sustancias o el alcohol?',
        '¿Ha tenido problemas para seguir con sus responsabilidades diarias?',
        '¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?',
        '¿Ha pensado en buscar ayuda profesional para su salud mental?',
        '¿Ha recibido tratamiento para su salud mental en el pasado?',
        '¿Tiene antecedentes familiares de trastornos mentales?',
        '¿Tiene otras condiciones médicas que podrían afectar su salud mental?',
        '¿Toma algún medicamento que podría afectar su salud mental?',
        '¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?',
        '¿Ha tenido experiencias traumáticas en el pasado?',
        '¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?',
        '¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?',
        '¿Está dispuesto a buscar ayuda profesional si es necesario?',
        # ... (add the rest of the questions)
    ]

    answers = []
    for question in questionnaire:
        user_answer = input(question + " (yes/no): ").lower()
        answers.append(user_answer)

   # Perform sentiment analysis on the questionnaire responses
    sentiment_result = perform_sentiment_analysis(answers)
    print("Sentiment analysis result for the questionnaire: ", sentiment_result)

    # Process answers or take further actions based on the responses

def chatbot_response(user_input):
    response = respond(user_input)
    print('Chatbot: ' + response)

    if any(greeting_pattern in user_input.lower() for greeting_pattern in initial_greeting_corpus):
        initial_greeting()
    elif any(questionnaire_pattern in user_input.lower() for questionnaire_pattern in questionnaire_corpus):
        handle_questionnaire()
    elif any(end_pattern in user_input.lower() for end_pattern in end_conversation_corpus):
        print("Ending the conversation. Goodbye!")
        # break

# def disclaimer():
#     print('Disclaimer: This chatbot is not a substitute for professional medical advice. It is intended to provide general information and support.')
#     print('If you are experiencing mental health symptoms, please seek professional help.')
#     print('This chatbot is not intended to diagnose, treat, or cure any mental health conditions.')
#     print('User data may be shared with third parties for the purpose of providing and improving the chatbot.')
#     print('If you are in crisis, please seek professional help immediately.')
#     print('You can contact the National Suicide Prevention Lifeline at 1-800-273-TALK (1-800-273-8255) or text "MHA" to 741741 to speak with a trained crisis counselor.')

# def initial_greeting():
#     print("Welcome to the Mental Health Chatbot!")
#     print("I'm here to provide information and support. You can type 'quit' at any time to exit the chat.")
#     print("How can I assist you today?")

# disclaimer()
# initial_greeting()

# while True:
#     user_input = input('You: ')
#     if user_input.lower() == 'quit':
#         break
#     chatbot_response(user_input)

# %%
def disclaimer():
    print('Disclaimer: This chatbot is not a substitute for professional medical advice. It is intended to provide general information and support.')
    print('If you are experiencing mental health symptoms, please seek professional help.')
    print('This chatbot is not intended to diagnose, treat, or cure any mental health conditions.')
    print('User data may be shared with third parties for the purpose of providing and improving the chatbot.')
    print('If you are in crisis, please seek professional help immediately.')
    print('You can contact the National Suicide Prevention Lifeline at 1-800-273-TALK (1-800-273-8255) or text "MHA" to 741741 to speak with a trained crisis counselor.')

def initial_greeting():
    print("Welcome to the Mental Health Chatbot!")
    print("I'm here to provide information and support. You can type 'quit' at any time to exit the chat.")
    print("How can I assist you today?")

disclaimer()
initial_greeting()

# %%
while True:
    user_input = input('You: ')
    if user_input.lower() == 'quit':
        break
    chatbot_response(user_input)

# %%
import tensorflow as tf
import nltk
import spacy
import transformers
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from spacy.lang.en.stop_words import STOP_WORDS
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, GlobalMaxPooling1D

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

nlp = spacy.load('en_core_web_sm')
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
model = TFAutoModelForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

intents = [
    {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey']},
    {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
    {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
]

entities = [
    {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress']}
]

initial_greeting_corpus = [
    'hi',
    'hello',
    'hey',
    'greetings',
    'good morning',
    'good afternoon',
    'good evening',
    'welcome',
    'start chat',
    'begin conversation'
]

questionnaire_corpus = [
    'start test',
    'begin test',
    'start questionnaire',
    'mental health test',
    'assess my mood',
    'check my feelings',
    'evaluate my mental health',
    'answer some questions'
]

end_conversation_corpus = [
    'quit',
    'exit',
    'goodbye',
    'bye',
    'see you later',
    'end chat',
    'finish conversation',
    'stop chatting'
]

def preprocess(text):
    doc = nlp(text)
    tokens = [token.lemma_.lower().strip() for token in doc if token.lemma_ != '-PRON-' and token.lemma_ not in stop_words]
    return ' '.join(tokens)

def respond(user_input):
    user_input = preprocess(user_input)
    input_ids = tokenizer.encode(user_input, return_tensors='tf')
    output = model(input_ids)
    predicted_sentiment = tf.argmax(output[0], axis=-1)

    if predicted_sentiment == 0:
        return 'I am glad you are feeling positive today!'
    elif predicted_sentiment == 1:
        return 'I am sorry to hear that you are feeling neutral today. Can I help you with anything?'
    else:
        return 'I am sorry to hear that you are feeling negative today. Can I help you with anything?'

def handle_questionnaire():
    print("Let's start the mental health questionnaire:")
    questionnaire = [
        "Have you had difficulty sleeping for more than two weeks?",
        "Have you lost interest in activities you used to enjoy?",
        "Do you feel sad or depressed most of the time?",
        '¿Ha tenido dificultades para dormir durante más de dos semanas?',
        '¿Ha perdido el interés en actividades que solía disfrutar?',
        '¿Se siente triste o deprimido la mayor parte del tiempo?',
        '¿Tiene pensamientos negativos sobre usted mismo o el mundo?',
        '¿Ha tenido problemas para concentrarse o recordar cosas?',
        '¿Siente que se mueve más lento o que sus movimientos son torpes?',
        '¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?',
        '¿Se siente agitado o ansioso la mayor parte del tiempo?',
        '¿Tiene problemas para conciliar el sueño o despertarse temprano?',
        '¿Se siente irritable o fácilmente molesto?',
        '¿Se siente fatigado o sin energía la mayor parte del tiempo?',
        '¿Ha tenido problemas para controlar su impulso o comportamiento?',
        '¿Se ha sentido inseguro o preocupado por su apariencia física?',
        '¿Ha tenido problemas para relacionarse con los demás?',
        '¿Se ha sentido como si estuviera observando su vida desde afuera?',
        '¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?',
        '¿Ha tenido un episodio de manía o hipomanía?',
        '¿Ha tenido problemas con el abuso de sustancias o el alcohol?',
        '¿Ha tenido problemas para seguir con sus responsabilidades diarias?',
        '¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?',
        '¿Ha pensado en buscar ayuda profesional para su salud mental?',
        '¿Ha recibido tratamiento para su salud mental en el pasado?',
        '¿Tiene antecedentes familiares de trastornos mentales?',
        '¿Tiene otras condiciones médicas que podrían afectar su salud mental?',
        '¿Toma algún medicamento que podría afectar su salud mental?',
        '¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?',
        '¿Ha tenido experiencias traumáticas en el pasado?',
        '¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?',
        '¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?',
        '¿Está dispuesto a buscar ayuda profesional si es necesario?',
        # ... (add the rest of the questions)
    ]

    answers = []
    for question in questionnaire:
        user_answer = input(question + " (yes/no): ").lower()
        answers.append(user_answer)

    # Perform sentiment analysis on the questionnaire responses
    sentiment_result = perform_sentiment_analysis(answers)
    print("Sentiment analysis result for the questionnaire: ", sentiment_result)

    # Process answers or take further actions based on the responses

def chatbot_response(user_input):
    response = respond(user_input)
    print('Chatbot: ' + response)

    if any(greeting_pattern in user_input.lower() for greeting_pattern in initial_greeting_corpus):
        initial_greeting()
    elif any(questionnaire_pattern in user_input.lower() for questionnaire_pattern in questionnaire_corpus):
        handle_questionnaire()
    elif any(end_pattern in user_input.lower() for end_pattern in end_conversation_corpus):
        print("Ending the conversation. Goodbye!")
        # break

# def disclaimer():
#     print('Disclaimer: This chatbot is not a substitute for professional medical advice. It is intended to provide general information and support.')
#     print('If you are experiencing mental health symptoms, please seek professional help.')
#     print('This chatbot is not intended to diagnose, treat, or cure any mental health conditions.')
#     print('User data may be shared with third parties for the purpose of providing and improving the chatbot.')
#     print('If you are in crisis, please seek professional help immediately.')
#     print('You can contact the National Suicide Prevention Lifeline at 1-800-273-TALK (1-800-273-8255) or text "MHA" to 741741 to speak with a trained crisis counselor.')

# def initial_greeting():
#     print("Welcome to the Mental Health Chatbot!")
#     print("I'm here to provide information and support. You can type 'quit' at any time to exit the chat.")
#     print("How can I assist you today?")

# disclaimer()
# initial_greeting()

# while True:
#     user_input = input('You: ')
#     if user_input.lower() == 'quit':
#         break
#     chatbot_response(user_input)

# %%
# def disclaimer():
#     print('Disclaimer: This chatbot is not a substitute for professional medical advice. It is intended to provide general information and support.')
#     print('If you are experiencing mental health symptoms, please seek professional help.')
#     print('This chatbot is not intended to diagnose, treat, or cure any mental health conditions.')
#     print('User data may be shared with third parties for the purpose of providing and improving the chatbot.')
#     print('If you are in crisis, please seek professional help immediately.')
#     print('You can contact the National Suicide Prevention Lifeline at 1-800-273-TALK (1-800-273-8255) or text "MHA" to 741741 to speak with a trained crisis counselor.')

# def initial_greeting():
#     print("Welcome to the Mental Health Chatbot!")
#     print("I'm here to provide information and support. You can type 'quit' at any time to exit the chat.")
#     print("How can I assist you today?")

# disclaimer()
# initial_greeting()

# %%
# while True:
#     user_input = input('You: ')
#     if user_input.lower() == 'quit':
#         break
#     chatbot_response(user_input)

# %% [markdown]
# You can use the responses from the questionnaire to perform sentiment analysis.
#
# In this case, sentiment analysis could involve categorizing the overall sentiment of the responses as positive, neutral, or negative.
#
# Here's how you can modify your code to include sentiment analysis of the questionnaire answers using a simple rule-based approach:

# %%
import tensorflow as tf
import nltk
import spacy
import transformers
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from spacy.lang.en.stop_words import STOP_WORDS
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, GlobalMaxPooling1D

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

nlp = spacy.load('en_core_web_sm')
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
model = TFAutoModelForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

intents = [
    {'intent': 'greetings', 'patterns': ['hi', 'hello', 'hey', 'good morning/afternoon/evening', 'how do you do?', 'pleased to meet you', 'it is a pleasure to meet you', 'good to see you', 'howdy', 'what is up?', 'how is it going?','long time no see' ,'hey there','hey man' , 'hey girl','what is new?','how are you doing?', 'all right, mate?', 'howyasay', 'g day','hola', 'que tal', 'guten tag', 'blimey! It is you!', 'hello there! how are you today?', 'how are you doing today?','howdy doody', 'top of the morning to you', 'greetings']},
    {'intent': 'goodbye', 'patterns': ['bye', 'goodbye', 'see you later']},
    {'intent': 'mental_health_questionnaire', 'patterns': ['start test', 'begin test', 'start questionnaire']}
]

entities = [
    {'entity': 'mental_health_condition', 'values': ['depression', 'anxiety', 'stress', 'worry', 'burden', 'load', 'concern','weight', 'mild', 'severe', 'tightness', 'tension', 'ache', 'pain','strain', 'job stress', 'financial stress', 'relationship stress', 'exam stress', 'public speaking stress', 'at my wit is end','be on edge', 'be under a gun', 'crack under pressure', 'feel like i am going to explode', 'have a lot of my plate', 'lose sleep over something', 'pull an all-nighter', 'sweet the small stuff', 'take it one day at a  time','the pressure is on', 'under pressure', 'wrack my brain' ]}
]

initial_greeting_corpus = [
    'hi',
    'hello',
    'hey',
    'greetings',
    'good morning',
    'good afternoon',
    'good evening',
    'welcome',
    'start chat',
    'begin conversation'
]

questionnaire_corpus = [
    'start test',
    'begin test',
    'start questionnaire',
    'mental health test',
    'assess my mood',
    'check my feelings',
    'evaluate my mental health',
    'answer some questions'
]

end_conversation_corpus = [
    'quit',
    'exit',
    'goodbye',
    'bye',
    'see you later',
    'end chat',
    'finish conversation',
    'stop chatting'
]

def preprocess(text):
    doc = nlp(text)
    tokens = [token.lemma_.lower().strip() for token in doc if token.lemma_ != '-PRON-' and token.lemma_ not in stop_words]
    return ' '.join(tokens)

def perform_sentiment_analysis(answers):
    # Rule-based sentiment analysis (modify as needed)
    positive_keywords = ['happy', 'good', 'satisfied', 'content', 'positive', 'content', 'joyful', 'cheerful', 'delighted', 'ecstatic', 'euphoric', 'joyful', 'jubilant', 'merry', 'mirthful', 'overjoyed', 'thrilled','blissful', 'contented', 'gleeful', 'glad', 'gratified', 'happy-go-lucky', 'lighthearted', 'pleased', 'satisfied', 'serene', 'thankful', 'tranquil', 'upbeat']
    negative_keywords = ['sad', 'bad', 'unhappy', 'negative', 'worried', 'upset', 'unhappy', 'miserable', 'sorrowful', 'heartbroken', 'gloomy', 'mournful', 'glum', 'dismal', 'dejected', 'downcast', 'melancholy','distressed', 'despondent', 'despairing', 'forlorn', 'anguished', 'grieving', 'lamentful', 'tearful', 'bereaved', 'devastated']

    positive_count = sum(answer.lower() in positive_keywords for answer in answers)
    negative_count = sum(answer.lower() in negative_keywords for answer in answers)

    if positive_count > negative_count:
        return 'positive'
    elif positive_count < negative_count:
        return 'negative'
    else:
        return 'neutral'

def respond(user_input):
    user_input = preprocess(user_input)
    input_ids = tokenizer.encode(user_input, return_tensors='tf')
    output = model(input_ids)
    predicted_sentiment = tf.argmax(output[0], axis=-1)

    if predicted_sentiment == 0:
        return 'I am glad you are feeling positive today!'
    elif predicted_sentiment == 1:
        return 'I am sorry to hear that you are feeling neutral today. Can I help you with anything?'
    else:
        return 'I am sorry to hear that you are feeling negative today. Can I help you with anything?'

def handle_questionnaire():
    print("Let's start the mental health questionnaire:")
    questionnaire = [
        'Have you had difficulty sleeping for more than two weeks?',
        'Have you lost interest in activities you used to enjoy?',
        'Do you feel sad or depressed most of the time?',
        '¿Ha tenido dificultades para dormir durante más de dos semanas?',
        '¿Ha perdido el interés en actividades que solía disfrutar?',
        '¿Se siente triste o deprimido la mayor parte del tiempo?',
        '¿Tiene pensamientos negativos sobre usted mismo o el mundo?',
        '¿Ha tenido problemas para concentrarse o recordar cosas?',
        '¿Siente que se mueve más lento o que sus movimientos son torpes?',
        '¿Ha tenido cambios en su apetito, ya sea perdiendo o ganando peso sin intentarlo?',
        '¿Se siente agitado o ansioso la mayor parte del tiempo?',
        '¿Tiene problemas para conciliar el sueño o despertarse temprano?',
        '¿Se siente irritable o fácilmente molesto?',
        '¿Se siente fatigado o sin energía la mayor parte del tiempo?',
        '¿Ha tenido problemas para controlar su impulso o comportamiento?',
        '¿Se ha sentido inseguro o preocupado por su apariencia física?',
        '¿Ha tenido problemas para relacionarse con los demás?',
        '¿Se ha sentido como si estuviera observando su vida desde afuera?',
        '¿Ha tenido pensamientos de lastimarse a sí mismo o a los demás?',
        '¿Ha tenido un episodio de manía o hipomanía?',
        '¿Ha tenido problemas con el abuso de sustancias o el alcohol?',
        '¿Ha tenido problemas para seguir con sus responsabilidades diarias?',
        '¿Ha tenido problemas en el trabajo, la escuela o en otros aspectos de su vida?',
        '¿Ha pensado en buscar ayuda profesional para su salud mental?',
        '¿Ha recibido tratamiento para su salud mental en el pasado?',
        '¿Tiene antecedentes familiares de trastornos mentales?',
        '¿Tiene otras condiciones médicas que podrían afectar su salud mental?',
        '¿Toma algún medicamento que podría afectar su salud mental?',
        '¿Ha dejado de tomar algún medicamento recetado sin consultar a su médico?',
        '¿Ha tenido experiencias traumáticas en el pasado?',
        '¿Se siente cómodo hablando sobre sus problemas de salud mental con los demás?',
        '¿Tiene un sistema de apoyo social que lo ayude a lidiar con el estrés y los problemas emocionales?',
        '¿Está dispuesto a buscar ayuda profesional si es necesario?',
        "¿Se ha sentido perfectamente bien de salud y en plena forma?",
        "¿Ha tenido la sensación de que necesita un reconstituyente?",
        "¿Se ha sentido agotado y sin fuerzas para nada?",
        "¿Ha tenido la sensación de que estaba enfermo?",
        "¿Ha padecido dolores de cabeza?",
        "¿Ha tenido sensación de opresión en la cabeza, o de que la cabeza le va a estallar?",
        "¿Ha tenido oleadas de calor o escalofríos?",
        "¿Sus preocupaciones le han hecho perder mucho sueño?",
        "¿He tenido dificultades para seguir durmiendo de un tirón toda la noche?",
        "¿Se ha notado constantemente agobiado y en tensión?",
        "¿Se ha sentido con los nervios a flor de piel y malhumorado?",
        "¿Se ha asustado o ha tenido pánico sin motivo?",
        "¿Ha tenido sensación de que todo se le viene encima?",
        "¿Se ha notado nervioso y \"a punto de explotar\" contantemente?",
        "¿Se las ha arreglado para mantenerse ocupado y activo?",
        "¿Le cuesta más tiempo hacer las cosas?",
        "¿Ha tenido la impresión, en conjunto, de que está haciendo las cosas bien?",
        "¿Ha podido concentrarse en lo que estaba haciendo?",
        "¿Ha podido tomar decisiones con facilidad?",
        "¿Ha podido enfrentarse a sus problemas?",
        "¿Ha podido superar las dificultades?",
        "¿Ha podido disfrutar de las actividades de su vida diaria?",
        "¿Ha podido enfrentarse a las cosas?",
        "¿Ha sido capaz de sentirse feliz, cuando las cosas iban bien?",
        "¿Ha podido reírse y ver el lado divertido de las cosas?",
        "¿Se ha sentido optimista respecto al futuro?",
        "¿Se ha sentido útil y necesario?",
        "¿Se ha sentido razonablemente seguro de sí mismo?"
        # ... (add the rest of the questions)
    ]

    answers = []
    for question in questionnaire:
        user_answer = input(question + " (yes/no): ").lower()
        answers.append(user_answer)

    # Perform sentiment analysis on the questionnaire responses
    sentiment_result = perform_sentiment_analysis(answers)
    print("Sentiment analysis result for the questionnaire: ", sentiment_result)

    # Process answers or take further actions based on the responses

def chatbot_response(user_input):
    response = respond(user_input)
    print('Chatbot: ' + response)

    if any(greeting_pattern in user_input.lower() for greeting_pattern in initial_greeting_corpus):
        initial_greeting()
    elif any(questionnaire_pattern in user_input.lower() for questionnaire_pattern in questionnaire_corpus):
        handle_questionnaire()
    elif any(end_pattern in user_input.lower() for end_pattern in end_conversation_corpus):
        print("Ending the conversation. Goodbye!")
#         break

# def disclaimer():
#     print('Disclaimer: This chatbot is not a substitute for professional medical advice. It is intended to provide general information and support.')
#     print('If you are experiencing mental health symptoms, please seek professional help.')
#     print('This chatbot is not intended to diagnose, treat, or cure any mental health conditions.')
#     print('User data may be shared with third parties for the purpose of providing and improving the chatbot.')
#     print('If you are in crisis, please seek professional help immediately.')
#     print('You can contact the National Suicide Prevention Lifeline at 1-800-273-TALK (1-800-273-8255) or text "MHA" to 741741 to speak with a trained crisis counselor.')

# def initial_greeting():
#     print("Welcome to the Mental Health Chatbot!")
#     print("I'm here to provide information and support. You can type 'quit' at any time to exit the chat.")
#     print("How can I assist you today?")

# disclaimer()
# initial_greeting()

# while True:
#     user_input = input('You: ')
#     if user_input.lower() == 'quit':
#         break
#     chatbot_response(user_input)

# %%
def disclaimer():
    print('Disclaimer: This chatbot is not a substitute for professional medical advice. It is intended to provide general information and support.')
    print('If you are experiencing mental health symptoms, please seek professional help.')
    print('This chatbot is not intended to diagnose, treat, or cure any mental health conditions.')
    print('User data may be shared with third parties for the purpose of providing and improving the chatbot.')
    print('If you are in crisis, please seek professional help immediately.')
    print('You can contact the National Suicide Prevention Lifeline at 1-800-273-TALK (1-800-273-8255) or text "MHA" to 741741 to speak with a trained crisis counselor.')

def initial_greeting():
    print("Welcome to the Mental Health Chatbot!")
    print("I'm here to provide information and support. You can type 'quit' at any time to exit the chat.")
    print("How can I assist you today?")

disclaimer()
initial_greeting()

# %%
while True:
    user_input = input('You: ')
    if user_input.lower() == 'quit':
        break
    chatbot_response(user_input)

# %%
n = int(input("Introduce un número entero positivo mayor que 2: "))
i = 2
while n % i != 0:
    i += 1
if i == n:
    print(str(n) + " es primo")
else:
    print(str(n) + " no es primo")

# %%
while True:
 i = input('Please enter \'Si\': ')
 if i.strip() == 'Si':
   break
# Out:
# Please enter 'Si': si
# Please enter 'Si': si
# Please enter 'Si': no
# Please enter 'Si': Si
